# %% [markdown]
# # Kinship Recognition
#
# Kinship Recognition is an emerging task in Computer Vision that aims to find out if there is a kinship relationship between certain subjects through the images of their faces. The areas of application of kinship verification include **annotating images**, **organizing family albums**, **forensic investigation**, **surveillance**, and more. However, verifying kinship through facial images is challenging as such images contain high intra-variances, which vary by age, gender and other biological characteristics that are often not discriminable by the human eye. Over the years, many more and more effective methods have been developed to solve the problem.
#
# This notebook deals with the recognition of kinship through **neural networks**, in particular using **Siamese Networks**. You can choose to use two main approaches to solve the problem: the first approach uses a **naive** Siamese network, while the second approach uses the **transfer-learning** technique to import **pre-trained networks** such as **DenseNet** and **ResNet**.

# %% [markdown]
# # Import Google Drive
#
# Google Drive is imported because the "train.zip" and "test.zip" files are loaded on the drive, in the "ComputerVisionProject" folder

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Imports

# %%
# Data manipulation
import numpy as np
import pandas as pd

# Data visualisation
import matplotlib.pyplot as plt

# Fastai 
from fastai.vision import *
from fastai.vision.models import *

# PyTorch
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision.transforms as transforms
import torchvision.utils
import torchvision.datasets as dset

from torch import optim
from torch.utils.data import DataLoader,Dataset
from torchvision.models import *
from torchvision.datasets import ImageFolder
from torch.autograd import Variable

# TorchVision models
import torchvision.models as models

from pathlib import Path
import sys

from glob import glob
from PIL import Image

# Random
np.random.seed(42)

# %%
# The train.zip file is unzipped in the (local) "train" folder
# !unzip "/content/drive/MyDrive/ComputerVisionProject/kinship-dataset/train.zip" -d "train"
# Out:
# Output streaming troncato alle ultime 5000 righe.
#   inflating: train/F0099/MID1/P11523_face3.jpg
#   inflating: train/F0099/MID1/P11536_face2.jpg
#   inflating: train/F0099/MID1/P01025_face1.jpg
#   inflating: train/F0099/MID1/P11539_face1.jpg
#   inflating: train/F0099/MID1/P01021_face1.jpg
#   inflating: train/F0099/MID1/P01026_face1.jpg
#   inflating: train/F0099/MID1/P11519_face3.jpg
#   inflating: train/F0099/MID1/P11535_face2.jpg
#   inflating: train/F0099/MID1/P01027_face1.jpg
#   inflating: train/F0099/MID1/P11518_face2.jpg
#   inflating: train/F0099/MID1/P11520_face3.jpg
#   inflating: train/F0099/MID6/P11523_face2.jpg
#   inflating: train/F0099/MID6/P11518_face4.jpg
#   inflating: train/F0099/MID6/P11522_face4.jpg
#   inflating: train/F0099/MID6/P11519_face2.jpg
#   inflating: train/F0099/MID6/P11539_face2.jpg
#   inflating: train/F0099/MID3/P01019_face3.jpg
#   inflating: train/F0099/MID3/P01021_face3.jpg
#   inflating: train/F0099/MID3/P11518_face3.jpg
#   inflating: train/F0099/MID3/P11520_face2.jpg
#   inflating: train/F0099/MID3/P11519_face5.jpg
#   inflating: train/F0099/MID3/P01020_face3.jpg
#    creating: train/F0268/MID1/
#    creating: train/F0268/MID2/
#   inflating: train/F0268/MID2/P02840_face2.jpg
#   inflating: train/F0268/MID2/P02842_face2.jpg
#   inflating: train/F0268/MID2/P02839_face1.jpg
#   inflating: train/F0268/MID2/P02844_face2.jpg
#   inflating: train/F0268/MID2/P02841_face1.jpg
#   inflating: train/F0268/MID1/P02843_face1.jpg
#   inflating: train/F0268/MID1/P02841_face2.jpg
#   inflating: train/F0268/MID1/P02846_face1.jpg
#   inflating: train/F0268/MID1/P02844_face1.jpg
#   inflating: train/F0268/MID1/P02842_face1.jpg
#   inflating: train/F0268/MID1/P02840_face1.jpg
#   inflating: train/F0268/MID1/P02839_face3.jpg
#   inflating: train/F0268/MID1/P02845_face1.jpg
#    creating: train/F0579/MID1/
#    creating: train/F0579/MID2/
#    creating: train/F0579/MID3/
#    creating: train/F0579/MID4/
#    creating: train/F0579/MID5/
#    creating: train/F0579/MID6/
#    creating: train/F0579/MID7/
#    creating: train/F0579/MID8/
#    creating: train/F0579/MID9/
#   inflating: train/F0579/MID4/P06080_face2.jpg
#   inflating: train/F0579/MID4/P06076_face2.jpg
#   inflating: train/F0579/MID4/P06085_face2.jpg
#   inflating: train/F0579/MID4/P06081_face5.jpg
#   inflating: train/F0579/MID4/P06086_face5.jpg
#   inflating: train/F0579/MID4/P06079_face1.jpg
#   inflating: train/F0579/MID4/P06077_face3.jpg
#   inflating: train/F0579/MID4/P06087_face1.jpg
#   inflating: train/F0579/MID9/P06082_face1.jpg
#   inflating: train/F0579/MID9/P06078_face1.jpg
#   inflating: train/F0579/MID9/P06077_face2.jpg
#   inflating: train/F0579/MID5/P06086_face4.jpg
#   inflating: train/F0579/MID5/P06087_face2.jpg
#   inflating: train/F0579/MID5/P06081_face3.jpg
#   inflating: train/F0579/MID5/P06085_face1.jpg
#   inflating: train/F0579/MID5/P06084_face1.jpg
#   inflating: train/F0579/MID5/P06077_face5.jpg
#   inflating: train/F0579/MID5/P06083_face2.jpg
#   inflating: train/F0579/MID5/P06082_face3.jpg
#   inflating: train/F0579/MID7/P06082_face4.jpg
#   inflating: train/F0579/MID7/P06080_face1.jpg
#   inflating: train/F0579/MID7/P06079_face2.jpg
#   inflating: train/F0579/MID7/P06086_face1.jpg
#   inflating: train/F0579/MID7/P06081_face4.jpg
#   inflating: train/F0579/MID7/P06077_face4.jpg
#   inflating: train/F0579/MID2/P06075_face2.jpg
#   inflating: train/F0579/MID2/P06074_face3.jpg
#   inflating: train/F0579/MID8/P06082_face2.jpg
#   inflating: train/F0579/MID8/P06083_face3.jpg
#   inflating: train/F0579/MID8/P06077_face1.jpg
#   inflating: train/F0579/MID8/P06078_face2.jpg
#   inflating: train/F0579/MID1/P06075_face1.jpg
#   inflating: train/F0579/MID1/P06082_face5.jpg
#   inflating: train/F0579/MID1/P06074_face2.jpg
#   inflating: train/F0579/MID1/P06086_face3.jpg
#   inflating: train/F0579/MID1/P06083_face1.jpg
#   inflating: train/F0579/MID1/P06076_face1.jpg
#   inflating: train/F0579/MID1/P06081_face1.jpg
#   inflating: train/F0579/MID1/P06077_face6.jpg
#   inflating: train/F0579/MID6/P06086_face2.jpg
#   inflating: train/F0579/MID6/P06081_face2.jpg
#   inflating: train/F0579/MID6/P06077_face7.jpg
#   inflating: train/F0579/MID3/P06074_face1.jpg
#    creating: train/F0431/MID2/
#    creating: train/F0431/MID4/
#   inflating: train/F0431/MID4/P04538_face5.jpg
#   inflating: train/F0431/MID4/P04537_face1.jpg
#   inflating: train/F0431/MID4/P04540_face1.jpg
#   inflating: train/F0431/MID2/P04536_face2.jpg
#   inflating: train/F0431/MID2/P04532_face1.jpg
#   inflating: train/F0431/MID2/P04533_face1.jpg
#   inflating: train/F0431/MID2/P04535_face1.jpg
#   inflating: train/F0431/MID2/P04534_face1.jpg
#   inflating: train/F0431/MID2/P04538_face2.jpg
#   inflating: train/F0431/MID2/P04539_face1.jpg
#    creating: train/F0659/MID1/
#    creating: train/F0659/MID2/
#   inflating: train/F0659/MID2/P06906_face1.jpg
#   inflating: train/F0659/MID2/P06902_face2.jpg
#   inflating: train/F0659/MID2/P06907_face1.jpg
#   inflating: train/F0659/MID1/P06904_face1.jpg
#   inflating: train/F0659/MID1/P06903_face1.jpg
#   inflating: train/F0659/MID1/P06906_face2.jpg
#   inflating: train/F0659/MID1/P06902_face1.jpg
#    creating: train/F0241/MID1/
#    creating: train/F0241/MID2/
#    creating: train/F0241/MID3/
#   inflating: train/F0241/MID2/P02548_face2.jpg
#   inflating: train/F0241/MID2/P02555_face1.jpg
#   inflating: train/F0241/MID2/P02556_face2.jpg
#   inflating: train/F0241/MID2/P02552_face1.jpg
#   inflating: train/F0241/MID2/P02553_face1.jpg
#   inflating: train/F0241/MID2/P02549_face2.jpg
#   inflating: train/F0241/MID2/P02557_face1.jpg
#   inflating: train/F0241/MID1/P02552_face2.jpg
#   inflating: train/F0241/MID1/P02556_face1.jpg
#   inflating: train/F0241/MID1/P02548_face1.jpg
#   inflating: train/F0241/MID1/P02553_face2.jpg
#   inflating: train/F0241/MID1/P02549_face1.jpg
#   inflating: train/F0241/MID1/P02555_face2.jpg
#   inflating: train/F0241/MID1/P02550_face1.jpg
#   inflating: train/F0241/MID1/P02557_face2.jpg
#   inflating: train/F0241/MID1/P02554_face1.jpg
#   inflating: train/F0241/MID3/P02548_face3.jpg
#   inflating: train/F0241/MID3/P02551_face1.jpg
#   inflating: train/F0241/MID3/P02549_face3.jpg
#    creating: train/F0916/MID1/
#    creating: train/F0916/MID2/
#    creating: train/F0916/MID3/
#   inflating: train/F0916/MID2/P09674_face2.jpg
#   inflating: train/F0916/MID2/P09671_face2.jpg
#   inflating: train/F0916/MID2/P09667_face2.jpg
#   inflating: train/F0916/MID2/P09666_face2.jpg
#   inflating: train/F0916/MID2/P09668_face2.jpg
#   inflating: train/F0916/MID2/P09670_face2.jpg
#   inflating: train/F0916/MID2/P09665_face2.jpg
#   inflating: train/F0916/MID1/P09665_face3.jpg
#   inflating: train/F0916/MID1/P09672_face1.jpg
#   inflating: train/F0916/MID1/P09674_face1.jpg
#   inflating: train/F0916/MID1/P09667_face1.jpg
#   inflating: train/F0916/MID1/P09670_face1.jpg
#   inflating: train/F0916/MID1/P09671_face1.jpg
#   inflating: train/F0916/MID1/P09669_face1.jpg
#   inflating: train/F0916/MID1/P09668_face1.jpg
#   inflating: train/F0916/MID1/P09666_face1.jpg
#   inflating: train/F0916/MID3/P09665_face1.jpg
#   inflating: train/F0916/MID3/P09672_face3.jpg
#   inflating: train/F0916/MID3/P09673_face1.jpg
#   inflating: train/F0916/MID3/P09669_face2.jpg
#    creating: train/F0623/MID1/
#    creating: train/F0623/MID2/
#   inflating: train/F0623/MID2/P06553_face2.jpg
#   inflating: train/F0623/MID2/P06547_face3.jpg
#   inflating: train/F0623/MID2/P06554_face2.jpg
#   inflating: train/F0623/MID2/P06546_face2.jpg
#   inflating: train/F0623/MID2/P06548_face3.jpg
#   inflating: train/F0623/MID2/P06549_face1.jpg
#   inflating: train/F0623/MID2/P06552_face3.jpg
#   inflating: train/F0623/MID2/P06544_face2.jpg
#   inflating: train/F0623/MID2/P06550_face2.jpg
#   inflating: train/F0623/MID2/P06545_face2.jpg
#   inflating: train/F0623/MID2/P06551_face1.jpg
#   inflating: train/F0623/MID1/P06549_face2.jpg
#   inflating: train/F0623/MID1/P06544_face1.jpg
#   inflating: train/F0623/MID1/P06553_face1.jpg
#   inflating: train/F0623/MID1/P06554_face1.jpg
#   inflating: train/F0623/MID1/P06546_face1.jpg
#   inflating: train/F0623/MID1/P06552_face2.jpg
#   inflating: train/F0623/MID1/P06547_face2.jpg
#   inflating: train/F0623/MID1/P06548_face2.jpg
#   inflating: train/F0623/MID1/P06550_face1.jpg
#   inflating: train/F0623/MID1/P06551_face2.jpg
#   inflating: train/F0623/MID1/P06545_face1.jpg
#    creating: train/F0884/MID1/
#    creating: train/F0884/MID2/
#    creating: train/F0884/MID3/
#   inflating: train/F0884/MID2/P09326_face2.jpg
#   inflating: train/F0884/MID2/P09328_face1.jpg
#   inflating: train/F0884/MID2/P09327_face1.jpg
#   inflating: train/F0884/MID2/P09330_face1.jpg
#   inflating: train/F0884/MID2/P09334_face2.jpg
#   inflating: train/F0884/MID2/P09333_face1.jpg
#   inflating: train/F0884/MID2/P09325_face2.jpg
#   inflating: train/F0884/MID1/P09333_face2.jpg
#   inflating: train/F0884/MID1/P09325_face1.jpg
#   inflating: train/F0884/MID1/P09331_face2.jpg
#   inflating: train/F0884/MID1/P09328_face2.jpg
#   inflating: train/F0884/MID1/P09326_face1.jpg
#   inflating: train/F0884/MID1/P09329_face2.jpg
#   inflating: train/F0884/MID3/P09331_face1.jpg
#   inflating: train/F0884/MID3/P09332_face1.jpg
#   inflating: train/F0884/MID3/P09330_face2.jpg
#   inflating: train/F0884/MID3/P09329_face1.jpg
#   inflating: train/F0884/MID3/P09327_face3.jpg
#   inflating: train/F0884/MID3/P09334_face1.jpg
#    creating: train/F0646/MID1/
#    creating: train/F0646/MID2/
#    creating: train/F0646/MID3/
#    creating: train/F0646/MID4/
#    creating: train/F0646/MID5/
#    creating: train/F0646/MID6/
#   inflating: train/F0646/MID4/P06803_face6.jpg
#   inflating: train/F0646/MID5/P06804_face3.jpg
#   inflating: train/F0646/MID5/P06810_face1.jpg
#   inflating: train/F0646/MID5/P06805_face1.jpg
#   inflating: train/F0646/MID5/P06811_face1.jpg
#   inflating: train/F0646/MID5/P06803_face3.jpg
#   inflating: train/F0646/MID5/P06808_face1.jpg
#   inflating: train/F0646/MID2/P06803_face4.jpg
#   inflating: train/F0646/MID2/P06809_face2.jpg
#   inflating: train/F0646/MID1/P06806_face2.jpg
#   inflating: train/F0646/MID1/P06807_face2.jpg
#   inflating: train/F0646/MID1/P06803_face5.jpg
#   inflating: train/F0646/MID1/P06804_face2.jpg
#   inflating: train/F0646/MID1/P06805_face3.jpg
#   inflating: train/F0646/MID1/P06811_face3.jpg
#   inflating: train/F0646/MID1/P06809_face1.jpg
#   inflating: train/F0646/MID6/P06810_face2.jpg
#   inflating: train/F0646/MID6/P06804_face1.jpg
#   inflating: train/F0646/MID6/P06803_face2.jpg
#   inflating: train/F0646/MID3/P06808_face3.jpg
#   inflating: train/F0646/MID3/P06807_face1.jpg
#   inflating: train/F0646/MID3/P06803_face1.jpg
#   inflating: train/F0646/MID3/P06806_face1.jpg
#   inflating: train/F0646/MID3/P06811_face2.jpg
#    creating: train/F0122/MID1/
#    creating: train/F0122/MID2/
#    creating: train/F0122/MID3/
#    creating: train/F0122/MID4/
#    creating: train/F0122/MID5/
#    creating: train/F0122/MID7/
#   inflating: train/F0122/MID4/P01268_face1.jpg
#   inflating: train/F0122/MID5/P01269_face2.jpg
#   inflating: train/F0122/MID7/P01274_face2.jpg
#   inflating: train/F0122/MID7/P01273_face2.jpg
#   inflating: train/F0122/MID2/P01268_face4.jpg
#   inflating: train/F0122/MID1/P01273_face1.jpg
#   inflating: train/F0122/MID1/P01269_face1.jpg
#   inflating: train/F0122/MID1/P01268_face3.jpg
#   inflating: train/F0122/MID1/P01271_face3.jpg
#   inflating: train/F0122/MID1/P01274_face1.jpg
#   inflating: train/F0122/MID3/P01268_face2.jpg
#    creating: train/F0960/MID1/
#    creating: train/F0960/MID2/
#    creating: train/F0960/MID3/
#    creating: train/F0960/MID4/
#    creating: train/F0960/MID5/
#    creating: train/F0960/MID6/
#   inflating: train/F0960/MID4/P10112_face5.jpg
#   inflating: train/F0960/MID4/P10116_face4.jpg
#   inflating: train/F0960/MID5/P10112_face2.jpg
#   inflating: train/F0960/MID5/P10116_face1.jpg
#   inflating: train/F0960/MID2/P10115_face3.jpg
#   inflating: train/F0960/MID2/P10117_face2.jpg
#   inflating: train/F0960/MID2/P10112_face1.jpg
#   inflating: train/F0960/MID2/P10119_face2.jpg
#   inflating: train/F0960/MID2/P10111_face3.jpg
#   inflating: train/F0960/MID2/P10116_face3.jpg
#   inflating: train/F0960/MID1/P10117_face1.jpg
#   inflating: train/F0960/MID1/P10114_face1.jpg
#   inflating: train/F0960/MID1/P10116_face5.jpg
#   inflating: train/F0960/MID1/P10113_face2.jpg
#   inflating: train/F0960/MID1/P10111_face2.jpg
#   inflating: train/F0960/MID1/P10115_face2.jpg
#   inflating: train/F0960/MID1/P10119_face1.jpg
#   inflating: train/F0960/MID1/P10118_face3.jpg
#   inflating: train/F0960/MID1/P10112_face3.jpg
#   inflating: train/F0960/MID1/P10120_face1.jpg
#   inflating: train/F0960/MID6/P10120_face2.jpg
#   inflating: train/F0960/MID3/P10111_face1.jpg
#   inflating: train/F0960/MID3/P10112_face4.jpg
#   inflating: train/F0960/MID3/P10113_face1.jpg
#   inflating: train/F0960/MID3/P10116_face2.jpg
#   inflating: train/F0960/MID3/P10115_face1.jpg
#   inflating: train/F0960/MID3/P10118_face2.jpg
#   inflating: train/F0960/MID3/P10114_face2.jpg
#    creating: train/F0974/MID1/
#    creating: train/F0974/MID2/
#    creating: train/F0974/MID3/
#    creating: train/F0974/MID5/
#    creating: train/F0974/MID6/
#    creating: train/F0974/MID7/
#   inflating: train/F0974/MID5/P10270_face2.jpg
#   inflating: train/F0974/MID5/P10268_face2.jpg
#   inflating: train/F0974/MID5/P10264_face4.jpg
#   inflating: train/F0974/MID5/P10269_face3.jpg
#   inflating: train/F0974/MID7/P10266_face4.jpg
#   inflating: train/F0974/MID2/P10264_face1.jpg
#   inflating: train/F0974/MID2/P10263_face4.jpg
#   inflating: train/F0974/MID2/P10270_face3.jpg
#   inflating: train/F0974/MID2/P10272_face1.jpg
#   inflating: train/F0974/MID2/P10266_face6.jpg
#   inflating: train/F0974/MID2/P10265_face1.jpg
#   inflating: train/F0974/MID2/P10268_face1.jpg
#   inflating: train/F0974/MID1/P10270_face4.jpg
#   inflating: train/F0974/MID1/P10264_face3.jpg
#   inflating: train/F0974/MID1/P10271_face1.jpg
#   inflating: train/F0974/MID1/P10266_face7.jpg
#   inflating: train/F0974/MID1/P10272_face2.jpg
#   inflating: train/F0974/MID1/P10265_face3.jpg
#   inflating: train/F0974/MID1/P10263_face1.jpg
#   inflating: train/F0974/MID1/P10269_face1.jpg
#   inflating: train/F0974/MID1/P10267_face2.jpg
#   inflating: train/F0974/MID6/P10266_face2.jpg
#   inflating: train/F0974/MID6/P10271_face2.jpg
#   inflating: train/F0974/MID3/P10264_face2.jpg
#   inflating: train/F0974/MID3/P10265_face2.jpg
#   inflating: train/F0974/MID3/P10263_face3.jpg
#   inflating: train/F0974/MID3/P10268_face3.jpg
#   inflating: train/F0974/MID3/P10272_face3.jpg
#   inflating: train/F0974/MID3/P10269_face2.jpg
#   inflating: train/F0974/MID3/P10267_face1.jpg
#   inflating: train/F0974/MID3/P10270_face1.jpg
#    creating: train/F0584/MID1/
#    creating: train/F0584/MID2/
#    creating: train/F0584/MID3/
#    creating: train/F0584/MID4/
#   inflating: train/F0584/MID4/P06143_face1.jpg
#   inflating: train/F0584/MID2/P06146_face1.jpg
#   inflating: train/F0584/MID2/P06145_face1.jpg
#   inflating: train/F0584/MID2/P06144_face1.jpg
#   inflating: train/F0584/MID2/P06148_face2.jpg
#   inflating: train/F0584/MID1/P06150_face1.jpg
#   inflating: train/F0584/MID1/P06149_face2.jpg
#   inflating: train/F0584/MID1/P06148_face1.jpg
#   inflating: train/F0584/MID1/P06152_face2.jpg
#   inflating: train/F0584/MID1/P06147_face1.jpg
#   inflating: train/F0584/MID1/P06143_face2.jpg
#   inflating: train/F0584/MID3/P06149_face1.jpg
#    creating: train/F0959/MID1/
#    creating: train/F0959/MID2/
#    creating: train/F0959/MID3/
#    creating: train/F0959/MID4/
#    creating: train/F0959/MID5/
#   inflating: train/F0959/MID4/P10108_face3.jpg
#   inflating: train/F0959/MID5/P10110_face2.jpg
#   inflating: train/F0959/MID5/P10107_face2.jpg
#   inflating: train/F0959/MID5/P10105_face1.jpg
#   inflating: train/F0959/MID5/P10108_face2.jpg
#   inflating: train/F0959/MID5/P10104_face4.jpg
#   inflating: train/F0959/MID5/P10102_face1.jpg
#   inflating: train/F0959/MID5/P10106_face2.jpg
#   inflating: train/F0959/MID5/P10103_face4.jpg
#   inflating: train/F0959/MID5/P10109_face2.jpg
#   inflating: train/F0959/MID2/P10104_face3.jpg
#   inflating: train/F0959/MID2/P10103_face1.jpg
#   inflating: train/F0959/MID2/P10102_face3.jpg
#   inflating: train/F0959/MID2/P10101_face2.jpg
#   inflating: train/F0959/MID2/P10106_face1.jpg
#   inflating: train/F0959/MID1/P10105_face2.jpg
#   inflating: train/F0959/MID1/P10106_face3.jpg
#   inflating: train/F0959/MID1/P10103_face3.jpg
#   inflating: train/F0959/MID1/P10110_face1.jpg
#   inflating: train/F0959/MID1/P10107_face1.jpg
#   inflating: train/F0959/MID1/P10108_face1.jpg
#   inflating: train/F0959/MID1/P10102_face2.jpg
#   inflating: train/F0959/MID1/P10101_face1.jpg
#   inflating: train/F0959/MID1/P10104_face1.jpg
#   inflating: train/F0959/MID1/P10109_face1.jpg
#   inflating: train/F0959/MID3/P10103_face2.jpg
#   inflating: train/F0959/MID3/P10101_face3.jpg
#   inflating: train/F0959/MID3/P10102_face4.jpg
#   inflating: train/F0959/MID3/P10104_face2.jpg
#    creating: train/F0737/MID1/
#    creating: train/F0737/MID2/
#    creating: train/F0737/MID3/
#    creating: train/F0737/MID4/
#    creating: train/F0737/MID5/
#   inflating: train/F0737/MID4/P07727_face1.jpg
#   inflating: train/F0737/MID4/P07721_face3.jpg
#   inflating: train/F0737/MID4/P07723_face2.jpg
#   inflating: train/F0737/MID4/P07720_face3.jpg
#   inflating: train/F0737/MID5/P07725_face1.jpg
#   inflating: train/F0737/MID5/P07721_face2.jpg
#   inflating: train/F0737/MID2/P07719_face2.jpg
#   inflating: train/F0737/MID2/P07724_face1.jpg
#   inflating: train/F0737/MID2/P07718_face2.jpg
#   inflating: train/F0737/MID1/P07722_face1.jpg
#   inflating: train/F0737/MID1/P07721_face1.jpg
#   inflating: train/F0737/MID1/P07720_face2.jpg
#   inflating: train/F0737/MID1/P07723_face1.jpg
#   inflating: train/F0737/MID1/P07719_face1.jpg
#   inflating: train/F0737/MID1/P07718_face1.jpg
#   inflating: train/F0737/MID1/P07724_face2.jpg
#   inflating: train/F0737/MID3/P07720_face1.jpg
#   inflating: train/F0737/MID3/P07721_face4.jpg
#   inflating: train/F0737/MID3/P07722_face2.jpg
#    creating: train/F0168/MID1/
#    creating: train/F0168/MID2/
#    creating: train/F0168/MID3/
#    creating: train/F0168/MID4/
#   inflating: train/F0168/MID4/P01813_face3.jpg
#   inflating: train/F0168/MID4/P01810_face3.jpg
#   inflating: train/F0168/MID4/P01807_face3.jpg
#   inflating: train/F0168/MID4/P01805_face4.jpg
#   inflating: train/F0168/MID2/P01805_face1.jpg
#   inflating: train/F0168/MID2/P01808_face3.jpg
#   inflating: train/F0168/MID2/P01814_face1.jpg
#   inflating: train/F0168/MID2/P01810_face2.jpg
#   inflating: train/F0168/MID2/P01807_face4.jpg
#   inflating: train/F0168/MID1/P01805_face2.jpg
#   inflating: train/F0168/MID1/P01813_face2.jpg
#   inflating: train/F0168/MID1/P01810_face1.jpg
#   inflating: train/F0168/MID1/P01812_face1.jpg
#   inflating: train/F0168/MID1/P01807_face2.jpg
#   inflating: train/F0168/MID1/P01814_face2.jpg
#   inflating: train/F0168/MID3/P01810_face4.jpg
#   inflating: train/F0168/MID3/P01813_face4.jpg
#   inflating: train/F0168/MID3/P01807_face1.jpg
#   inflating: train/F0168/MID3/P01812_face2.jpg
#   inflating: train/F0168/MID3/P01805_face3.jpg
#    creating: train/F0468/MID1/
#    creating: train/F0468/MID2/
#    creating: train/F0468/MID3/
#    creating: train/F0468/MID4/
#   inflating: train/F0468/MID4/P04937_face3.jpg
#   inflating: train/F0468/MID4/P04936_face2.jpg
#   inflating: train/F0468/MID2/P04936_face3.jpg
#   inflating: train/F0468/MID2/P04934_face1.jpg
#   inflating: train/F0468/MID2/P04935_face1.jpg
#   inflating: train/F0468/MID2/P04937_face1.jpg
#   inflating: train/F0468/MID2/P04939_face1.jpg
#   inflating: train/F0468/MID2/P04933_face1.jpg
#   inflating: train/F0468/MID2/P04938_face1.jpg
#   inflating: train/F0468/MID1/P04933_face3.jpg
#   inflating: train/F0468/MID1/P04937_face2.jpg
#   inflating: train/F0468/MID1/P04935_face3.jpg
#   inflating: train/F0468/MID1/P04940_face2.jpg
#   inflating: train/F0468/MID1/P04939_face3.jpg
#   inflating: train/F0468/MID1/P04938_face2.jpg
#   inflating: train/F0468/MID1/P04936_face1.jpg
#   inflating: train/F0468/MID1/P04934_face2.jpg
#   inflating: train/F0468/MID3/P04935_face2.jpg
#   inflating: train/F0468/MID3/P04939_face2.jpg
#   inflating: train/F0468/MID3/P04940_face1.jpg
#   inflating: train/F0468/MID3/P04936_face4.jpg
#   inflating: train/F0468/MID3/P04937_face4.jpg
#   inflating: train/F0468/MID3/P04938_face3.jpg
#   inflating: train/F0468/MID3/P04934_face3.jpg
#   inflating: train/F0468/MID3/P04933_face2.jpg
#    creating: train/F0195/MID1/
#    creating: train/F0195/MID2/
#    creating: train/F0195/MID3/
#   inflating: train/F0195/MID2/P02097_face2.jpg
#   inflating: train/F0195/MID2/P02099_face1.jpg
#   inflating: train/F0195/MID1/P02101_face1.jpg
#   inflating: train/F0195/MID1/P02100_face1.jpg
#   inflating: train/F0195/MID1/P02102_face2.jpg
#   inflating: train/F0195/MID1/P02099_face2.jpg
#   inflating: train/F0195/MID1/P02097_face1.jpg
#   inflating: train/F0195/MID1/P02098_face1.jpg
#   inflating: train/F0195/MID3/P02101_face2.jpg
#   inflating: train/F0195/MID3/P02102_face1.jpg
#    creating: train/F0126/MID1/
#    creating: train/F0126/MID2/
#    creating: train/F0126/MID3/
#    creating: train/F0126/MID4/
#    creating: train/F0126/MID5/
#    creating: train/F0126/MID6/
#   inflating: train/F0126/MID4/P01310_face2.jpg
#   inflating: train/F0126/MID4/P01304_face2.jpg
#   inflating: train/F0126/MID4/P01303_face2.jpg
#   inflating: train/F0126/MID5/P01305_face1.jpg
#   inflating: train/F0126/MID5/P01307_face1.jpg
#   inflating: train/F0126/MID5/P01306_face1.jpg
#   inflating: train/F0126/MID2/P01313_face2.jpg
#   inflating: train/F0126/MID2/P01297_face2.jpg
#   inflating: train/F0126/MID2/P01299_face1.jpg
#   inflating: train/F0126/MID2/P01306_face2.jpg
#   inflating: train/F0126/MID2/P01309_face3.jpg
#   inflating: train/F0126/MID2/P01301_face2.jpg
#   inflating: train/F0126/MID2/P01307_face2.jpg
#   inflating: train/F0126/MID2/P01305_face3.jpg
#   inflating: train/F0126/MID2/P01298_face2.jpg
#   inflating: train/F0126/MID1/P01308_face2.jpg
#   inflating: train/F0126/MID1/P01310_face1.jpg
#   inflating: train/F0126/MID1/P01298_face1.jpg
#   inflating: train/F0126/MID1/P01313_face1.jpg
#   inflating: train/F0126/MID1/P01304_face1.jpg
#   inflating: train/F0126/MID1/P01311_face2.jpg
#   inflating: train/F0126/MID1/P01299_face2.jpg
#   inflating: train/F0126/MID1/P01297_face1.jpg
#   inflating: train/F0126/MID1/P01309_face1.jpg
#   inflating: train/F0126/MID1/P01303_face1.jpg
#   inflating: train/F0126/MID1/P01300_face1.jpg
#   inflating: train/F0126/MID1/P01301_face3.jpg
#   inflating: train/F0126/MID6/P01306_face3.jpg
#   inflating: train/F0126/MID6/P01305_face2.jpg
#   inflating: train/F0126/MID3/P01302_face1.jpg
#   inflating: train/F0126/MID3/P01300_face2.jpg
#   inflating: train/F0126/MID3/P01301_face1.jpg
#    creating: train/F0983/MID1/
#    creating: train/F0983/MID2/
#    creating: train/F0983/MID3/
#    creating: train/F0983/MID4/
#   inflating: train/F0983/MID4/P10359_face1.jpg
#   inflating: train/F0983/MID4/P10360_face1.jpg
#   inflating: train/F0983/MID4/P10357_face2.jpg
#   inflating: train/F0983/MID4/P10362_face3.jpg
#   inflating: train/F0983/MID4/P10355_face1.jpg
#   inflating: train/F0983/MID4/P10354_face2.jpg
#   inflating: train/F0983/MID2/P10362_face1.jpg
#   inflating: train/F0983/MID2/P10353_face2.jpg
#   inflating: train/F0983/MID1/P10353_face1.jpg
#   inflating: train/F0983/MID1/P10362_face4.jpg
#   inflating: train/F0983/MID1/P10354_face1.jpg
#   inflating: train/F0983/MID1/P10358_face2.jpg
#   inflating: train/F0983/MID1/P10356_face2.jpg
#   inflating: train/F0983/MID1/P10355_face2.jpg
#   inflating: train/F0983/MID1/P10361_face2.jpg
#   inflating: train/F0983/MID1/P10360_face3.jpg
#   inflating: train/F0983/MID1/P10357_face1.jpg
#   inflating: train/F0983/MID1/P10359_face2.jpg
#   inflating: train/F0983/MID3/P10356_face1.jpg
#   inflating: train/F0983/MID3/P10362_face2.jpg
#   inflating: train/F0983/MID3/P10361_face1.jpg
#   inflating: train/F0983/MID3/P10360_face2.jpg
#   inflating: train/F0983/MID3/P10354_face3.jpg
#   inflating: train/F0983/MID3/P10358_face1.jpg
#   inflating: train/F0983/MID3/P10355_face3.jpg
#    creating: train/F0868/MID1/
#    creating: train/F0868/MID2/
#    creating: train/F0868/MID3/
#   inflating: train/F0868/MID2/P09168_face2.jpg
#   inflating: train/F0868/MID2/P09172_face1.jpg
#   inflating: train/F0868/MID2/P09173_face2.jpg
#   inflating: train/F0868/MID2/P09165_face2.jpg
#   inflating: train/F0868/MID2/P09167_face2.jpg
#   inflating: train/F0868/MID2/P09174_face2.jpg
#   inflating: train/F0868/MID1/P09174_face1.jpg
#   inflating: train/F0868/MID1/P09166_face1.jpg
#   inflating: train/F0868/MID1/P09168_face1.jpg
#   inflating: train/F0868/MID1/P09173_face1.jpg
#   inflating: train/F0868/MID1/P09170_face1.jpg
#   inflating: train/F0868/MID1/P09165_face1.jpg
#   inflating: train/F0868/MID1/P09167_face1.jpg
#   inflating: train/F0868/MID1/P09172_face2.jpg
#   inflating: train/F0868/MID1/P09169_face2.jpg
#   inflating: train/F0868/MID3/P09169_face1.jpg
#   inflating: train/F0868/MID3/P09171_face1.jpg
#   inflating: train/F0868/MID3/P09170_face2.jpg
#    creating: train/F0769/MID1/
#    creating: train/F0769/MID2/
#    creating: train/F0769/MID3/
#    creating: train/F0769/MID4/
#    creating: train/F0769/MID5/
#    creating: train/F0769/MID6/
#    creating: train/F0769/MID7/
#   inflating: train/F0769/MID4/P08121_face3.jpg
#   inflating: train/F0769/MID4/P08120_face1.jpg
#   inflating: train/F0769/MID4/P08119_face2.jpg
#   inflating: train/F0769/MID4/P08123_face4.jpg
#   inflating: train/F0769/MID5/P08124_face1.jpg
#   inflating: train/F0769/MID5/P08125_face1.jpg
#   inflating: train/F0769/MID7/P08124_face2.jpg
#   inflating: train/F0769/MID2/P08119_face4.jpg
#   inflating: train/F0769/MID2/P08123_face3.jpg
#   inflating: train/F0769/MID2/P08116_face2.jpg
#   inflating: train/F0769/MID2/P08118_face2.jpg
#   inflating: train/F0769/MID2/P08121_face2.jpg
#   inflating: train/F0769/MID1/P08121_face4.jpg
#   inflating: train/F0769/MID1/P08123_face1.jpg
#   inflating: train/F0769/MID1/P08120_face2.jpg
#   inflating: train/F0769/MID1/P08119_face1.jpg
#   inflating: train/F0769/MID1/P08125_face2.jpg
#   inflating: train/F0769/MID1/P08128_face2.jpg
#   inflating: train/F0769/MID1/P08116_face3.jpg
#   inflating: train/F0769/MID1/P08127_face1.jpg
#   inflating: train/F0769/MID1/P08118_face4.jpg
#   inflating: train/F0769/MID6/P08127_face2.jpg
#   inflating: train/F0769/MID6/P08128_face3.jpg
#   inflating: train/F0769/MID3/P08116_face1.jpg
#   inflating: train/F0769/MID3/P08118_face1.jpg
#   inflating: train/F0769/MID3/P08121_face5.jpg
#   inflating: train/F0769/MID3/P08119_face3.jpg
#    creating: train/F0050/MID1/
#    creating: train/F0050/MID2/
#    creating: train/F0050/MID3/
#   inflating: train/F0050/MID2/P00504_face1.jpg
#   inflating: train/F0050/MID2/P00502_face1.jpg
#   inflating: train/F0050/MID2/P00501_face1.jpg
#   inflating: train/F0050/MID2/P00507_face1.jpg
#   inflating: train/F0050/MID2/P00503_face3.jpg
#   inflating: train/F0050/MID2/P00508_face1.jpg
#   inflating: train/F0050/MID1/P00499_face1.jpg
#   inflating: train/F0050/MID1/P00505_face1.jpg
#   inflating: train/F0050/MID1/P00504_face2.jpg
#   inflating: train/F0050/MID1/P00501_face2.jpg
#   inflating: train/F0050/MID1/P00506_face1.jpg
#   inflating: train/F0050/MID1/P00502_face2.jpg
#   inflating: train/F0050/MID1/P00508_face2.jpg
#   inflating: train/F0050/MID3/P00507_face2.jpg
#   inflating: train/F0050/MID3/P00503_face1.jpg
#   inflating: train/F0050/MID3/P00500_face1.jpg
#    creating: train/F0077/MID1/
#    creating: train/F0077/MID2/
#    creating: train/F0077/MID3/
#    creating: train/F0077/MID4/
#    creating: train/F0077/MID6/
#   inflating: train/F0077/MID4/P00784_face1.jpg
#   inflating: train/F0077/MID2/P00783_face4.jpg
#   inflating: train/F0077/MID2/P00784_face3.jpg
#   inflating: train/F0077/MID2/P00792_face2.jpg
#   inflating: train/F0077/MID1/P00791_face3.jpg
#   inflating: train/F0077/MID1/P00790_face3.jpg
#   inflating: train/F0077/MID1/P00789_face3.jpg
#   inflating: train/F0077/MID1/P00794_face2.jpg
#   inflating: train/F0077/MID1/P00786_face3.jpg
#   inflating: train/F0077/MID1/P00784_face4.jpg
#   inflating: train/F0077/MID1/P00785_face2.jpg
#   inflating: train/F0077/MID1/P00787_face2.jpg
#   inflating: train/F0077/MID1/P00793_face2.jpg
#   inflating: train/F0077/MID1/P00783_face3.jpg
#   inflating: train/F0077/MID6/P00786_face1.jpg
#   inflating: train/F0077/MID6/P00789_face2.jpg
#   inflating: train/F0077/MID6/P00787_face1.jpg
#   inflating: train/F0077/MID3/P00790_face1.jpg
#   inflating: train/F0077/MID3/P00792_face3.jpg
#   inflating: train/F0077/MID3/P00791_face1.jpg
#   inflating: train/F0077/MID3/P00793_face1.jpg
#   inflating: train/F0077/MID3/P00794_face1.jpg
#   inflating: train/F0077/MID3/P00785_face1.jpg
#   inflating: train/F0077/MID3/P00783_face1.jpg
#    creating: train/F0791/MID1/
#    creating: train/F0791/MID2/
#    creating: train/F0791/MID3/
#    creating: train/F0791/MID4/
#    creating: train/F0791/MID5/
#    creating: train/F0791/MID6/
#    creating: train/F0791/MID8/
#   inflating: train/F0791/MID4/P08334_face1.jpg
#   inflating: train/F0791/MID4/P08341_face3.jpg
#   inflating: train/F0791/MID4/P08335_face3.jpg
#   inflating: train/F0791/MID5/P08334_face3.jpg
#   inflating: train/F0791/MID5/P08333_face1.jpg
#   inflating: train/F0791/MID5/P08335_face1.jpg
#   inflating: train/F0791/MID2/P08337_face2.jpg
#   inflating: train/F0791/MID2/P08336_face1.jpg
#   inflating: train/F0791/MID8/P08336_face5.jpg
#   inflating: train/F0791/MID1/P08341_face2.jpg
#   inflating: train/F0791/MID1/P08337_face1.jpg
#   inflating: train/F0791/MID1/P08336_face2.jpg
#   inflating: train/F0791/MID1/P08334_face4.jpg
#   inflating: train/F0791/MID6/P08334_face5.jpg
#   inflating: train/F0791/MID3/P08341_face1.jpg
#   inflating: train/F0791/MID3/P08334_face2.jpg
#   inflating: train/F0791/MID3/P08333_face4.jpg
#   inflating: train/F0791/MID3/P08335_face2.jpg
#    creating: train/F0427/MID1/
#    creating: train/F0427/MID2/
#    creating: train/F0427/MID3/
#    creating: train/F0427/MID4/
#    creating: train/F0427/MID5/
#    creating: train/F0427/MID6/
#   inflating: train/F0427/MID4/P04496_face2.jpg
#   inflating: train/F0427/MID4/P04497_face1.jpg
#   inflating: train/F0427/MID4/P04491_face1.jpg
#   inflating: train/F0427/MID4/P04492_face1.jpg
#   inflating: train/F0427/MID4/P04494_face3.jpg
#   inflating: train/F0427/MID4/P04490_face5.jpg
#   inflating: train/F0427/MID4/P04495_face4.jpg
#   inflating: train/F0427/MID4/P04493_face3.jpg
#   inflating: train/F0427/MID4/P04498_face2.jpg
#   inflating: train/F0427/MID4/P04499_face2.jpg
#   inflating: train/F0427/MID5/P04490_face4.jpg
#   inflating: train/F0427/MID5/P04494_face4.jpg
#   inflating: train/F0427/MID2/P04496_face4.jpg
#   inflating: train/F0427/MID2/P04495_face3.jpg
#   inflating: train/F0427/MID2/P04497_face3.jpg
#   inflating: train/F0427/MID2/P04490_face3.jpg
#   inflating: train/F0427/MID2/P04499_face4.jpg
#   inflating: train/F0427/MID2/P04493_face4.jpg
#   inflating: train/F0427/MID2/P04494_face5.jpg
#   inflating: train/F0427/MID2/P04491_face2.jpg
#   inflating: train/F0427/MID1/P04498_face1.jpg
#   inflating: train/F0427/MID1/P04492_face3.jpg
#   inflating: train/F0427/MID1/P04497_face4.jpg
#   inflating: train/F0427/MID1/P04495_face1.jpg
#   inflating: train/F0427/MID1/P04499_face3.jpg
#   inflating: train/F0427/MID1/P04496_face1.jpg
#   inflating: train/F0427/MID1/P04490_face2.jpg
#   inflating: train/F0427/MID1/P04493_face1.jpg
#   inflating: train/F0427/MID1/P04494_face1.jpg
#   inflating: train/F0427/MID6/P04494_face6.jpg
#   inflating: train/F0427/MID6/P04499_face5.jpg
#   inflating: train/F0427/MID6/P04490_face6.jpg
#   inflating: train/F0427/MID6/P04491_face4.jpg
#   inflating: train/F0427/MID6/P04493_face5.jpg
#   inflating: train/F0427/MID3/P04491_face3.jpg
#   inflating: train/F0427/MID3/P04499_face1.jpg
#   inflating: train/F0427/MID3/P04498_face4.jpg
#   inflating: train/F0427/MID3/P04495_face2.jpg
#   inflating: train/F0427/MID3/P04492_face2.jpg
#   inflating: train/F0427/MID3/P04497_face2.jpg
#   inflating: train/F0427/MID3/P04494_face2.jpg
#   inflating: train/F0427/MID3/P04490_face1.jpg
#   inflating: train/F0427/MID3/P04493_face2.jpg
#   inflating: train/F0427/MID3/P04496_face5.jpg
#    creating: train/F0303/MID1/
#    creating: train/F0303/MID10/
#    creating: train/F0303/MID11/
#    creating: train/F0303/MID2/
#    creating: train/F0303/MID3/
#    creating: train/F0303/MID4/
#    creating: train/F0303/MID5/
#    creating: train/F0303/MID6/
#    creating: train/F0303/MID8/
#   inflating: train/F0303/MID4/P12187_face1.jpg
#   inflating: train/F0303/MID4/P12186_face1.jpg
#   inflating: train/F0303/MID4/P12168_face1.jpg
#   inflating: train/F0303/MID4/P12143_face2.jpg
#   inflating: train/F0303/MID4/P12170_face1.jpg
#   inflating: train/F0303/MID4/P12188_face1.jpg
#   inflating: train/F0303/MID4/P12185_face2.jpg
#   inflating: train/F0303/MID4/P12166_face1.jpg
#   inflating: train/F0303/MID4/P12169_face3.jpg
#   inflating: train/F0303/MID4/P12167_face1.jpg
#   inflating: train/F0303/MID4/P12171_face1.jpg
#   inflating: train/F0303/MID11/P12160_face1.jpg
#   inflating: train/F0303/MID10/P12144_face1.jpg
#   inflating: train/F0303/MID10/P12162_face2.jpg
#   inflating: train/F0303/MID5/P12184_face3.jpg
#   inflating: train/F0303/MID5/P12175_face2.jpg
#   inflating: train/F0303/MID2/P12161_face1.jpg
#   inflating: train/F0303/MID2/P12158_face1.jpg
#   inflating: train/F0303/MID2/P12128_face1.jpg
#   inflating: train/F0303/MID2/P12149_face1.jpg
#   inflating: train/F0303/MID2/P12155_face1.jpg
#   inflating: train/F0303/MID2/P12157_face2.jpg
#   inflating: train/F0303/MID2/P12154_face1.jpg
#   inflating: train/F0303/MID2/P12150_face1.jpg
#   inflating: train/F0303/MID2/P12153_face1.jpg
#   inflating: train/F0303/MID2/P12151_face1.jpg
#   inflating: train/F0303/MID2/P12159_face2.jpg
#   inflating: train/F0303/MID2/P12152_face1.jpg
#   inflating: train/F0303/MID8/P12178_face3.jpg
#   inflating: train/F0303/MID8/P12180_face2.jpg
#   inflating: train/F0303/MID8/P12177_face1.jpg
#   inflating: train/F0303/MID1/P12125_face1.jpg
#   inflating: train/F0303/MID1/P12179_face1.jpg
#   inflating: train/F0303/MID1/P12185_face1.jpg
#   inflating: train/F0303/MID1/P12146_face1.jpg
#   inflating: train/F0303/MID1/P12147_face1.jpg
#   inflating: train/F0303/MID1/P12124_face1.jpg
#   inflating: train/F0303/MID1/P12170_face2.jpg
#   inflating: train/F0303/MID1/P12121_face1.jpg
#   inflating: train/F0303/MID1/P12189_face1.jpg
#   inflating: train/F0303/MID1/P12180_face1.jpg
#   inflating: train/F0303/MID1/P12157_face1.jpg
#   inflating: train/F0303/MID1/P12122_face1.jpg
#   inflating: train/F0303/MID1/P12123_face1.jpg
#   inflating: train/F0303/MID1/P12145_face1.jpg
#   inflating: train/F0303/MID1/P12176_face1.jpg
#   inflating: train/F0303/MID1/P12178_face1.jpg
#   inflating: train/F0303/MID1/P12159_face1.jpg
#   inflating: train/F0303/MID1/P12164_face1.jpg
#   inflating: train/F0303/MID1/P12172_face1.jpg
#   inflating: train/F0303/MID1/P12175_face4.jpg
#   inflating: train/F0303/MID1/P12182_face1.jpg
#   inflating: train/F0303/MID1/P12165_face1.jpg
#   inflating: train/F0303/MID1/P12126_face1.jpg
#   inflating: train/F0303/MID1/P12184_face2.jpg
#   inflating: train/F0303/MID1/P12169_face2.jpg
#   inflating: train/F0303/MID1/P12144_face2.jpg
#   inflating: train/F0303/MID1/P12127_face1.jpg
#   inflating: train/F0303/MID1/P12120_face1.jpg
#   inflating: train/F0303/MID6/P12183_face1.jpg
#   inflating: train/F0303/MID3/P12129_face1.jpg
#    creating: train/F0526/MID1/
#    creating: train/F0526/MID2/
#    creating: train/F0526/MID3/
#    creating: train/F0526/MID4/
#    creating: train/F0526/MID5/
#   inflating: train/F0526/MID4/P05533_face3.jpg
#   inflating: train/F0526/MID5/P05533_face2.jpg
#   inflating: train/F0526/MID2/P05528_face1.jpg
#   inflating: train/F0526/MID2/P05524_face1.jpg
#   inflating: train/F0526/MID2/P05531_face1.jpg
#   inflating: train/F0526/MID1/P05527_face2.jpg
#   inflating: train/F0526/MID1/P05530_face2.jpg
#   inflating: train/F0526/MID1/P05528_face2.jpg
#   inflating: train/F0526/MID1/P05524_face2.jpg
#   inflating: train/F0526/MID1/P05532_face2.jpg
#   inflating: train/F0526/MID1/P05531_face2.jpg
#   inflating: train/F0526/MID1/P05529_face2.jpg
#   inflating: train/F0526/MID1/P05525_face1.jpg
#   inflating: train/F0526/MID1/P05533_face1.jpg
#   inflating: train/F0526/MID1/P05526_face3.jpg
#   inflating: train/F0526/MID3/P05530_face1.jpg
#   inflating: train/F0526/MID3/P05525_face6.jpg
#   inflating: train/F0526/MID3/P05532_face1.jpg
#   inflating: train/F0526/MID3/P05526_face1.jpg
#   inflating: train/F0526/MID3/P05528_face3.jpg
#   inflating: train/F0526/MID3/P05527_face1.jpg
#    creating: train/F0840/MID1/
#    creating: train/F0840/MID3/
#   inflating: train/F0840/MID1/P08872_face1.jpg
#   inflating: train/F0840/MID1/P08874_face1.jpg
#   inflating: train/F0840/MID1/P08880_face1.jpg
#   inflating: train/F0840/MID1/P08875_face1.jpg
#   inflating: train/F0840/MID1/P08873_face1.jpg
#   inflating: train/F0840/MID1/P08877_face2.jpg
#   inflating: train/F0840/MID1/P08871_face1.jpg
#   inflating: train/F0840/MID1/P08878_face1.jpg
#   inflating: train/F0840/MID1/P08876_face2.jpg
#   inflating: train/F0840/MID3/P08874_face2.jpg
#   inflating: train/F0840/MID3/P08873_face3.jpg
#    creating: train/F0894/MID1/
#    creating: train/F0894/MID2/
#    creating: train/F0894/MID3/
#   inflating: train/F0894/MID2/P09436_face3.jpg
#   inflating: train/F0894/MID2/P09433_face2.jpg
#   inflating: train/F0894/MID2/P09434_face2.jpg
#   inflating: train/F0894/MID2/P09435_face2.jpg
#   inflating: train/F0894/MID2/P09437_face2.jpg
#   inflating: train/F0894/MID2/P09432_face2.jpg
#   inflating: train/F0894/MID2/P09438_face2.jpg
#   inflating: train/F0894/MID2/P09441_face2.jpg
#   inflating: train/F0894/MID1/P09438_face1.jpg
#   inflating: train/F0894/MID1/P09441_face1.jpg
#   inflating: train/F0894/MID1/P09439_face2.jpg
#   inflating: train/F0894/MID1/P09435_face3.jpg
#   inflating: train/F0894/MID1/P09432_face1.jpg
#   inflating: train/F0894/MID1/P09433_face4.jpg
#   inflating: train/F0894/MID1/P09434_face1.jpg
#   inflating: train/F0894/MID1/P09436_face2.jpg
#   inflating: train/F0894/MID1/P09440_face2.jpg
#   inflating: train/F0894/MID1/P09437_face1.jpg
#   inflating: train/F0894/MID3/P09436_face1.jpg
#   inflating: train/F0894/MID3/P09439_face1.jpg
#   inflating: train/F0894/MID3/P09440_face1.jpg
#    creating: train/F0231/MID1/
#    creating: train/F0231/MID10/
#    creating: train/F0231/MID11/
#    creating: train/F0231/MID12/
#    creating: train/F0231/MID14/
#    creating: train/F0231/MID3/
#    creating: train/F0231/MID4/
#    creating: train/F0231/MID5/
#    creating: train/F0231/MID6/
#    creating: train/F0231/MID7/
#    creating: train/F0231/MID8/
#    creating: train/F0231/MID9/
#   inflating: train/F0231/MID4/P11175_face1.jpg
#   inflating: train/F0231/MID4/P11181_face1.jpg
#   inflating: train/F0231/MID4/P11187_face2.jpg
#   inflating: train/F0231/MID4/P11176_face3.jpg
#   inflating: train/F0231/MID4/P11188_face1.jpg
#   inflating: train/F0231/MID4/P11185_face2.jpg
#   inflating: train/F0231/MID4/P11183_face5.jpg
#   inflating: train/F0231/MID4/P11184_face2.jpg
#   inflating: train/F0231/MID4/P11177_face1.jpg
#   inflating: train/F0231/MID4/P11174_face1.jpg
#   inflating: train/F0231/MID4/P11182_face5.jpg
#   inflating: train/F0231/MID14/P11189_face1.jpg
#   inflating: train/F0231/MID9/P11174_face4.jpg
#   inflating: train/F0231/MID9/P11185_face4.jpg
#   inflating: train/F0231/MID9/P11176_face5.jpg
#   inflating: train/F0231/MID9/P11183_face1.jpg
#   inflating: train/F0231/MID9/P11175_face4.jpg
#   inflating: train/F0231/MID9/P11182_face2.jpg
#   inflating: train/F0231/MID11/P11179_face1.jpg
#   inflating: train/F0231/MID11/P11171_face3.jpg
#   inflating: train/F0231/MID10/P11178_face1.jpg
#   inflating: train/F0231/MID10/P11168_face1.jpg
#   inflating: train/F0231/MID10/P11169_face1.jpg
#   inflating: train/F0231/MID10/P11181_face2.jpg
#   inflating: train/F0231/MID10/P02457_face1.jpg
#   inflating: train/F0231/MID10/P11171_face1.jpg
#   inflating: train/F0231/MID10/P02456_face1.jpg
#   inflating: train/F0231/MID5/P11184_face3.jpg
#   inflating: train/F0231/MID7/P02457_face2.jpg
#   inflating: train/F0231/MID7/P11178_face2.jpg
#   inflating: train/F0231/MID7/P11190_face3.jpg
#   inflating: train/F0231/MID8/P11177_face2.jpg
#   inflating: train/F0231/MID8/P11185_face1.jpg
#   inflating: train/F0231/MID8/P11176_face1.jpg
#   inflating: train/F0231/MID8/P11183_face2.jpg
#   inflating: train/F0231/MID8/P11182_face3.jpg
#   inflating: train/F0231/MID8/P11175_face2.jpg
#   inflating: train/F0231/MID8/P11174_face2.jpg
#   inflating: train/F0231/MID12/P11179_face2.jpg
#   inflating: train/F0231/MID1/P11171_face2.jpg
#   inflating: train/F0231/MID1/P11178_face3.jpg
#   inflating: train/F0231/MID1/P11170_face2.jpg
#   inflating: train/F0231/MID1/P02457_face3.jpg
#   inflating: train/F0231/MID1/P02456_face2.jpg
#   inflating: train/F0231/MID1/P11173_face1.jpg
#   inflating: train/F0231/MID1/P11168_face2.jpg
#   inflating: train/F0231/MID1/P11172_face1.jpg
#   inflating: train/F0231/MID1/P11181_face5.jpg
#   inflating: train/F0231/MID6/P11175_face5.jpg
#   inflating: train/F0231/MID6/P11177_face4.jpg
#   inflating: train/F0231/MID6/P11176_face4.jpg
#   inflating: train/F0231/MID6/P11183_face3.jpg
#   inflating: train/F0231/MID6/P11185_face5.jpg
#   inflating: train/F0231/MID6/P11182_face1.jpg
#   inflating: train/F0231/MID6/P11174_face3.jpg
#   inflating: train/F0231/MID3/P11174_face5.jpg
#   inflating: train/F0231/MID3/P11177_face3.jpg
#   inflating: train/F0231/MID3/P11176_face2.jpg
#   inflating: train/F0231/MID3/P11184_face1.jpg
#   inflating: train/F0231/MID3/P11185_face3.jpg
#   inflating: train/F0231/MID3/P11182_face6.jpg
#   inflating: train/F0231/MID3/P11189_face2.jpg
#   inflating: train/F0231/MID3/P11183_face4.jpg
#   inflating: train/F0231/MID3/P11175_face3.jpg
#   inflating: train/F0231/MID3/P11190_face2.jpg
#   inflating: train/F0231/MID3/P11176_face6.jpg
#   inflating: train/F0231/MID3/P11188_face2.jpg
#    creating: train/F0409/MID1/
#    creating: train/F0409/MID2/
#    creating: train/F0409/MID3/
#    creating: train/F0409/MID4/
#   inflating: train/F0409/MID4/P04306_face1.jpg
#   inflating: train/F0409/MID4/P04311_face2.jpg
#   inflating: train/F0409/MID4/P04310_face2.jpg
#   inflating: train/F0409/MID4/P04312_face1.jpg
#   inflating: train/F0409/MID4/P04309_face1.jpg
#   inflating: train/F0409/MID2/P04313_face3.jpg
#   inflating: train/F0409/MID2/P04305_face2.jpg
#   inflating: train/F0409/MID2/P04304_face1.jpg
#   inflating: train/F0409/MID1/P04304_face2.jpg
#   inflating: train/F0409/MID1/P04313_face1.jpg
#   inflating: train/F0409/MID1/P04305_face1.jpg
#   inflating: train/F0409/MID3/P04307_face2.jpg
#   inflating: train/F0409/MID3/P04313_face2.jpg
#   inflating: train/F0409/MID3/P04306_face2.jpg
#   inflating: train/F0409/MID3/P04310_face1.jpg
#   inflating: train/F0409/MID3/P04311_face1.jpg
#   inflating: train/F0409/MID3/P04308_face1.jpg
#   inflating: train/F0409/MID3/P04312_face2.jpg
#   inflating: train/F0409/MID3/P04305_face3.jpg
#   inflating: train/F0409/MID3/P04309_face2.jpg
#    creating: train/F0754/MID1/
#    creating: train/F0754/MID2/
#    creating: train/F0754/MID3/
#    creating: train/F0754/MID4/
#    creating: train/F0754/MID5/
#    creating: train/F0754/MID7/
#    creating: train/F0754/MID8/
#   inflating: train/F0754/MID4/P07970_face1.jpg
#   inflating: train/F0754/MID4/P07950_face1.jpg
#   inflating: train/F0754/MID4/P07937_face1.jpg
#   inflating: train/F0754/MID4/P07953_face1.jpg
#   inflating: train/F0754/MID4/P07938_face2.jpg
#   inflating: train/F0754/MID4/P07940_face2.jpg
#   inflating: train/F0754/MID4/P07955_face2.jpg
#   inflating: train/F0754/MID4/P07933_face4.jpg
#   inflating: train/F0754/MID4/P07951_face2.jpg
#   inflating: train/F0754/MID4/P07922_face2.jpg
#   inflating: train/F0754/MID4/P07944_face2.jpg
#   inflating: train/F0754/MID4/P07974_face1.jpg
#   inflating: train/F0754/MID4/P07961_face1.jpg
#   inflating: train/F0754/MID4/P07943_face1.jpg
#   inflating: train/F0754/MID4/P07920_face4.jpg
#   inflating: train/F0754/MID4/P07934_face1.jpg
#   inflating: train/F0754/MID4/P07935_face2.jpg
#   inflating: train/F0754/MID4/P07924_face3.jpg
#   inflating: train/F0754/MID4/P07928_face3.jpg
#   inflating: train/F0754/MID4/P07958_face3.jpg
#   inflating: train/F0754/MID4/P07936_face3.jpg
#   inflating: train/F0754/MID5/P07951_face3.jpg
#   inflating: train/F0754/MID5/P07937_face3.jpg
#   inflating: train/F0754/MID5/P07922_face4.jpg
#   inflating: train/F0754/MID5/P07955_face4.jpg
#   inflating: train/F0754/MID5/P07933_face5.jpg
#   inflating: train/F0754/MID5/P07954_face3.jpg
#   inflating: train/F0754/MID5/P07927_face3.jpg
#   inflating: train/F0754/MID5/P07924_face5.jpg
#   inflating: train/F0754/MID5/P07920_face2.jpg
#   inflating: train/F0754/MID7/P07963_face1.jpg
#   inflating: train/F0754/MID7/P07965_face1.jpg
#   inflating: train/F0754/MID7/P07962_face1.jpg
#   inflating: train/F0754/MID7/P07966_face1.jpg
#   inflating: train/F0754/MID7/P07968_face3.jpg
#   inflating: train/F0754/MID7/P07967_face3.jpg
#   inflating: train/F0754/MID2/P07937_face5.jpg
#   inflating: train/F0754/MID2/P07947_face1.jpg
#   inflating: train/F0754/MID2/P07948_face2.jpg
#   inflating: train/F0754/MID2/P07970_face4.jpg
#   inflating: train/F0754/MID2/P07938_face1.jpg
#   inflating: train/F0754/MID2/P07955_face3.jpg
#   inflating: train/F0754/MID2/P07971_face1.jpg
#   inflating: train/F0754/MID2/P07956_face1.jpg
#   inflating: train/F0754/MID2/P07922_face1.jpg
#   inflating: train/F0754/MID2/P07927_face1.jpg
#   inflating: train/F0754/MID2/P07924_face1.jpg
#   inflating: train/F0754/MID2/P07945_face2.jpg
#   inflating: train/F0754/MID2/P07953_face3.jpg
#   inflating: train/F0754/MID2/P07933_face1.jpg
#   inflating: train/F0754/MID2/P07925_face2.jpg
#   inflating: train/F0754/MID2/P07973_face1.jpg
#   inflating: train/F0754/MID2/P07928_face1.jpg
#   inflating: train/F0754/MID2/P07972_face2.jpg
#   inflating: train/F0754/MID2/P07958_face2.jpg
#   inflating: train/F0754/MID2/P07920_face5.jpg
#   inflating: train/F0754/MID2/P07954_face1.jpg
#   inflating: train/F0754/MID2/P07969_face2.jpg
#   inflating: train/F0754/MID2/P07944_face3.jpg
#   inflating: train/F0754/MID8/P07968_face1.jpg
#   inflating: train/F0754/MID1/P07973_face2.jpg
#   inflating: train/F0754/MID1/P07960_face1.jpg
#   inflating: train/F0754/MID1/P07945_face1.jpg
#   inflating: train/F0754/MID1/P07936_face2.jpg
#   inflating: train/F0754/MID1/P07939_face3.jpg
#   inflating: train/F0754/MID1/P07928_face2.jpg
#   inflating: train/F0754/MID1/P07944_face4.jpg
#   inflating: train/F0754/MID1/P07948_face3.jpg
#   inflating: train/F0754/MID1/P07956_face2.jpg
#   inflating: train/F0754/MID1/P07927_face2.jpg
#   inflating: train/F0754/MID1/P07940_face1.jpg
#   inflating: train/F0754/MID1/P07937_face4.jpg
#   inflating: train/F0754/MID1/P07953_face4.jpg
#   inflating: train/F0754/MID1/P07972_face3.jpg
#   inflating: train/F0754/MID1/P07958_face1.jpg
#   inflating: train/F0754/MID1/P07969_face1.jpg
#   inflating: train/F0754/MID1/P07971_face2.jpg
#   inflating: train/F0754/MID1/P07962_face2.jpg
#   inflating: train/F0754/MID1/P07961_face2.jpg
#   inflating: train/F0754/MID1/P07933_face3.jpg
#   inflating: train/F0754/MID1/P07920_face1.jpg
#   inflating: train/F0754/MID1/P07935_face1.jpg
#   inflating: train/F0754/MID1/P07970_face6.jpg
#   inflating: train/F0754/MID1/P07951_face1.jpg
#   inflating: train/F0754/MID1/P07952_face2.jpg
#   inflating: train/F0754/MID1/P07924_face4.jpg
#   inflating: train/F0754/MID1/P07925_face3.jpg
#   inflating: train/F0754/MID1/P07947_face3.jpg
#   inflating: train/F0754/MID1/P07954_face4.jpg
# ...
#   inflating: train/F0893/MID2/P09423_face5.jpg
#   inflating: train/F0893/MID2/P09430_face2.jpg
#   inflating: train/F0893/MID2/P09429_face1.jpg
#   inflating: train/F0893/MID1/P09429_face2.jpg
#   inflating: train/F0893/MID1/P09430_face1.jpg
#   inflating: train/F0893/MID1/P09425_face1.jpg
#   inflating: train/F0893/MID1/P09426_face2.jpg
#   inflating: train/F0893/MID1/P09427_face2.jpg
#   inflating: train/F0893/MID1/P09423_face1.jpg
#   inflating: train/F0893/MID1/P09424_face1.jpg
#   inflating: train/F0893/MID1/P09422_face2.jpg
#   inflating: train/F0893/MID1/P09428_face1.jpg
#   inflating: train/F0893/MID1/P09431_face2.jpg
#   inflating: train/F0893/MID3/P09424_face2.jpg
#   inflating: train/F0893/MID3/P09426_face1.jpg
#   inflating: train/F0893/MID3/P09427_face1.jpg
#   inflating: train/F0893/MID3/P09428_face2.jpg
#   inflating: train/F0893/MID3/P09422_face3.jpg
#   inflating: train/F0893/MID3/P09423_face2.jpg
#    creating: train/F0763/MID1/
#    creating: train/F0763/MID2/
#    creating: train/F0763/MID3/
#    creating: train/F0763/MID4/
#    creating: train/F0763/MID5/
#    creating: train/F0763/MID6/
#    creating: train/F0763/MID7/
#    creating: train/F0763/MID8/
#    creating: train/F0763/MID9/
#   inflating: train/F0763/MID4/P12191_face2.jpg
#   inflating: train/F0763/MID9/P12195_face3.jpg
#   inflating: train/F0763/MID9/P12193_face1.jpg
#   inflating: train/F0763/MID5/P12193_face7.jpg
#   inflating: train/F0763/MID5/P12191_face5.jpg
#   inflating: train/F0763/MID7/P12191_face6.jpg
#   inflating: train/F0763/MID7/P12194_face1.jpg
#   inflating: train/F0763/MID7/P12193_face5.jpg
#   inflating: train/F0763/MID7/P12195_face6.jpg
#   inflating: train/F0763/MID7/P12191_face3.jpg
#   inflating: train/F0763/MID2/P12191_face7.jpg
#   inflating: train/F0763/MID2/P12195_face5.jpg
#   inflating: train/F0763/MID2/P12197_face3.jpg
#   inflating: train/F0763/MID2/P12193_face3.jpg
#   inflating: train/F0763/MID2/P12192_face1.jpg
#   inflating: train/F0763/MID2/P12190_face2.jpg
#   inflating: train/F0763/MID2/P12198_face1.jpg
#   inflating: train/F0763/MID8/P12195_face1.jpg
#   inflating: train/F0763/MID8/P12193_face6.jpg
#   inflating: train/F0763/MID1/P12193_face4.jpg
#   inflating: train/F0763/MID1/P12199_face1.jpg
#   inflating: train/F0763/MID1/P12203_face1.jpg
#   inflating: train/F0763/MID1/P12196_face1.jpg
#   inflating: train/F0763/MID1/P12201_face1.jpg
#   inflating: train/F0763/MID1/P12191_face1.jpg
#   inflating: train/F0763/MID1/P12190_face1.jpg
#   inflating: train/F0763/MID1/P12202_face1.jpg
#   inflating: train/F0763/MID1/P12200_face1.jpg
#   inflating: train/F0763/MID1/P12197_face1.jpg
#   inflating: train/F0763/MID1/P12195_face4.jpg
#   inflating: train/F0763/MID6/P12197_face4.jpg
#   inflating: train/F0763/MID6/P12194_face2.jpg
#   inflating: train/F0763/MID3/P12200_face2.jpg
#   inflating: train/F0763/MID3/P12203_face2.jpg
#   inflating: train/F0763/MID3/P12193_face2.jpg
#   inflating: train/F0763/MID3/P12197_face2.jpg
#   inflating: train/F0763/MID3/P12196_face2.jpg
#   inflating: train/F0763/MID3/P12202_face2.jpg
#   inflating: train/F0763/MID3/P12191_face4.jpg
#   inflating: train/F0763/MID3/P12195_face2.jpg
#   inflating: train/F0763/MID3/P12201_face2.jpg
#   inflating: train/F0763/MID3/P12199_face2.jpg
#    creating: train/F0390/MID1/
#    creating: train/F0390/MID10/
#    creating: train/F0390/MID11/
#    creating: train/F0390/MID2/
#    creating: train/F0390/MID3/
#    creating: train/F0390/MID4/
#    creating: train/F0390/MID5/
#    creating: train/F0390/MID6/
#    creating: train/F0390/MID7/
#    creating: train/F0390/MID8/
#    creating: train/F0390/MID9/
#   inflating: train/F0390/MID4/P04134_face2.jpg
#   inflating: train/F0390/MID4/P04133_face2.jpg
#   inflating: train/F0390/MID4/P04137_face2.jpg
#   inflating: train/F0390/MID4/P04132_face3.jpg
#   inflating: train/F0390/MID9/P04128_face2.jpg
#   inflating: train/F0390/MID11/P04128_face4.jpg
#   inflating: train/F0390/MID10/P04128_face1.jpg
#   inflating: train/F0390/MID5/P04132_face2.jpg
#   inflating: train/F0390/MID5/P04138_face1.jpg
#   inflating: train/F0390/MID5/P04134_face3.jpg
#   inflating: train/F0390/MID5/P04127_face3.jpg
#   inflating: train/F0390/MID5/P04133_face3.jpg
#   inflating: train/F0390/MID7/P04136_face3.jpg
#   inflating: train/F0390/MID7/P04135_face1.jpg
#   inflating: train/F0390/MID2/P04129_face2.jpg
#   inflating: train/F0390/MID2/P04131_face3.jpg
#   inflating: train/F0390/MID2/P04128_face3.jpg
#   inflating: train/F0390/MID2/P04130_face2.jpg
#   inflating: train/F0390/MID8/P04135_face3.jpg
#   inflating: train/F0390/MID8/P04136_face1.jpg
#   inflating: train/F0390/MID1/P04130_face1.jpg
#   inflating: train/F0390/MID1/P04135_face2.jpg
#   inflating: train/F0390/MID1/P04138_face2.jpg
#   inflating: train/F0390/MID1/P04136_face2.jpg
#   inflating: train/F0390/MID1/P04128_face6.jpg
#   inflating: train/F0390/MID1/P04127_face2.jpg
#   inflating: train/F0390/MID1/P04133_face1.jpg
#   inflating: train/F0390/MID1/P04137_face1.jpg
#   inflating: train/F0390/MID1/P04132_face1.jpg
#   inflating: train/F0390/MID1/P04134_face1.jpg
#   inflating: train/F0390/MID1/P04129_face3.jpg
#   inflating: train/F0390/MID1/P04131_face2.jpg
#   inflating: train/F0390/MID6/P04133_face4.jpg
#   inflating: train/F0390/MID6/P04127_face1.jpg
#   inflating: train/F0390/MID6/P04132_face4.jpg
#   inflating: train/F0390/MID3/P04131_face1.jpg
#   inflating: train/F0390/MID3/P04128_face7.jpg
#   inflating: train/F0390/MID3/P04129_face1.jpg
#    creating: train/F0536/MID1/
#    creating: train/F0536/MID2/
#    creating: train/F0536/MID3/
#    creating: train/F0536/MID4/
#    creating: train/F0536/MID5/
#    creating: train/F0536/MID6/
#   inflating: train/F0536/MID4/P05634_face1.jpg
#   inflating: train/F0536/MID4/P05630_face1.jpg
#   inflating: train/F0536/MID4/P05633_face2.jpg
#   inflating: train/F0536/MID5/P05632_face3.jpg
#   inflating: train/F0536/MID2/P05634_face2.jpg
#   inflating: train/F0536/MID2/P05635_face2.jpg
#   inflating: train/F0536/MID1/P05632_face1.jpg
#   inflating: train/F0536/MID1/P05637_face2.jpg
#   inflating: train/F0536/MID1/P05633_face1.jpg
#   inflating: train/F0536/MID1/P05630_face2.jpg
#   inflating: train/F0536/MID1/P05631_face2.jpg
#   inflating: train/F0536/MID1/P05628_face1.jpg
#   inflating: train/F0536/MID6/P05635_face1.jpg
#   inflating: train/F0536/MID3/P05637_face1.jpg
#   inflating: train/F0536/MID3/P05629_face1.jpg
#   inflating: train/F0536/MID3/P05631_face1.jpg
#    creating: train/F0164/MID1/
#    creating: train/F0164/MID2/
#    creating: train/F0164/MID3/
#    creating: train/F0164/MID4/
#   inflating: train/F0164/MID4/P01758_face1.jpg
#   inflating: train/F0164/MID4/P01753_face1.jpg
#   inflating: train/F0164/MID4/P01762_face1.jpg
#   inflating: train/F0164/MID4/P01759_face1.jpg
#   inflating: train/F0164/MID4/P01760_face3.jpg
#   inflating: train/F0164/MID4/P01763_face2.jpg
#   inflating: train/F0164/MID4/P01757_face1.jpg
#   inflating: train/F0164/MID2/P01760_face1.jpg
#   inflating: train/F0164/MID2/P01771_face1.jpg
#   inflating: train/F0164/MID2/P01755_face2.jpg
#   inflating: train/F0164/MID2/P01752_face2.jpg
#   inflating: train/F0164/MID1/P01752_face1.jpg
#   inflating: train/F0164/MID1/P01756_face1.jpg
#   inflating: train/F0164/MID1/P01758_face2.jpg
#   inflating: train/F0164/MID1/P01766_face1.jpg
#   inflating: train/F0164/MID1/P01761_face2.jpg
#   inflating: train/F0164/MID1/P01770_face2.jpg
#   inflating: train/F0164/MID1/P01771_face2.jpg
#   inflating: train/F0164/MID1/P01768_face1.jpg
#   inflating: train/F0164/MID1/P01763_face1.jpg
#   inflating: train/F0164/MID1/P01757_face2.jpg
#   inflating: train/F0164/MID1/P01767_face3.jpg
#   inflating: train/F0164/MID1/P01759_face2.jpg
#   inflating: train/F0164/MID1/P01764_face2.jpg
#   inflating: train/F0164/MID1/P01765_face2.jpg
#   inflating: train/F0164/MID1/P01760_face2.jpg
#   inflating: train/F0164/MID3/P01770_face1.jpg
#   inflating: train/F0164/MID3/P01761_face1.jpg
#   inflating: train/F0164/MID3/P01753_face2.jpg
#   inflating: train/F0164/MID3/P01768_face2.jpg
#   inflating: train/F0164/MID3/P01762_face3.jpg
#   inflating: train/F0164/MID3/P01765_face1.jpg
#   inflating: train/F0164/MID3/P01764_face1.jpg
#   inflating: train/F0164/MID3/P01756_face2.jpg
#   inflating: train/F0164/MID3/P01752_face3.jpg
#   inflating: train/F0164/MID3/P01767_face2.jpg
#   inflating: train/F0164/MID3/P01766_face2.jpg
#    creating: train/F0856/MID1/
#    creating: train/F0856/MID3/
#   inflating: train/F0856/MID1/P09041_face1.jpg
#   inflating: train/F0856/MID1/P09046_face1.jpg
#   inflating: train/F0856/MID1/P09049_face2.jpg
#   inflating: train/F0856/MID1/P09042_face1.jpg
#   inflating: train/F0856/MID1/P09043_face1.jpg
#   inflating: train/F0856/MID1/P09047_face2.jpg
#   inflating: train/F0856/MID1/P09048_face2.jpg
#   inflating: train/F0856/MID1/P09044_face1.jpg
#   inflating: train/F0856/MID1/P09045_face2.jpg
#   inflating: train/F0856/MID3/P09046_face2.jpg
#   inflating: train/F0856/MID3/P09045_face1.jpg
#    creating: train/F0124/MID1/
#    creating: train/F0124/MID2/
#    creating: train/F0124/MID3/
#   inflating: train/F0124/MID2/P08629_face1.jpg
#   inflating: train/F0124/MID2/P08623_face2.jpg
#   inflating: train/F0124/MID2/P08625_face1.jpg
#   inflating: train/F0124/MID2/P08626_face3.jpg
#   inflating: train/F0124/MID2/P08622_face1.jpg
#   inflating: train/F0124/MID2/P08627_face1.jpg
#   inflating: train/F0124/MID2/P08624_face2.jpg
#   inflating: train/F0124/MID1/P08624_face1.jpg
#   inflating: train/F0124/MID1/P08623_face1.jpg
#   inflating: train/F0124/MID1/P08626_face2.jpg
#   inflating: train/F0124/MID1/P08628_face1.jpg
#   inflating: train/F0124/MID1/P08630_face1.jpg
#   inflating: train/F0124/MID1/P08627_face2.jpg
#   inflating: train/F0124/MID1/P08621_face2.jpg
#   inflating: train/F0124/MID3/P08626_face1.jpg
#   inflating: train/F0124/MID3/P08621_face1.jpg
#    creating: train/F0756/MID1/
#    creating: train/F0756/MID2/
#    creating: train/F0756/MID3/
#    creating: train/F0756/MID4/
#    creating: train/F0756/MID5/
#   inflating: train/F0756/MID4/P11245_face2.jpg
#   inflating: train/F0756/MID4/P11251_face3.jpg
#   inflating: train/F0756/MID5/P11249_face1.jpg
#   inflating: train/F0756/MID2/P11247_face1.jpg
#   inflating: train/F0756/MID2/P11246_face1.jpg
#   inflating: train/F0756/MID2/P11250_face3.jpg
#   inflating: train/F0756/MID2/P11251_face1.jpg
#   inflating: train/F0756/MID2/P11248_face2.jpg
#   inflating: train/F0756/MID2/P11245_face3.jpg
#   inflating: train/F0756/MID2/P07985_face1.jpg
#   inflating: train/F0756/MID2/P11252_face2.jpg
#   inflating: train/F0756/MID1/P11252_face1.jpg
#   inflating: train/F0756/MID1/P11249_face2.jpg
#   inflating: train/F0756/MID1/P11250_face1.jpg
#   inflating: train/F0756/MID1/P11248_face1.jpg
#   inflating: train/F0756/MID1/P07985_face2.jpg
#   inflating: train/F0756/MID1/P11245_face1.jpg
#   inflating: train/F0756/MID1/P11251_face2.jpg
#   inflating: train/F0756/MID1/P11246_face2.jpg
#   inflating: train/F0756/MID1/P11247_face2.jpg
#   inflating: train/F0756/MID3/P11246_face3.jpg
#   inflating: train/F0756/MID3/P11252_face3.jpg
#   inflating: train/F0756/MID3/P11250_face2.jpg
#   inflating: train/F0756/MID3/P11245_face4.jpg
#    creating: train/F0129/MID2/
#    creating: train/F0129/MID3/
#    creating: train/F0129/MID4/
#    creating: train/F0129/MID5/
#   inflating: train/F0129/MID4/P01340_face1.jpg
#   inflating: train/F0129/MID5/P01345_face2.jpg
#   inflating: train/F0129/MID5/P01346_face1.jpg
#   inflating: train/F0129/MID2/P01344_face2.jpg
#   inflating: train/F0129/MID2/P01348_face2.jpg
#   inflating: train/F0129/MID2/P01352_face1.jpg
#   inflating: train/F0129/MID2/P01353_face1.jpg
#   inflating: train/F0129/MID2/P01340_face3.jpg
#   inflating: train/F0129/MID2/P01350_face1.jpg
#   inflating: train/F0129/MID2/P01343_face3.jpg
#   inflating: train/F0129/MID3/P01343_face2.jpg
#   inflating: train/F0129/MID3/P01346_face2.jpg
#   inflating: train/F0129/MID3/P01340_face2.jpg
#   inflating: train/F0129/MID3/P01353_face2.jpg
#   inflating: train/F0129/MID3/P01345_face1.jpg
#   inflating: train/F0129/MID3/P01350_face2.jpg
#   inflating: train/F0129/MID3/P01344_face4.jpg
#   inflating: train/F0129/MID3/P01344_face3.jpg
#   inflating: train/F0129/MID3/P01343_face1.jpg
#   inflating: train/F0129/MID3/P01348_face1.jpg
#   inflating: train/F0129/MID3/P01352_face2.jpg
#    creating: train/F0169/MID1/
#    creating: train/F0169/MID2/
#    creating: train/F0169/MID3/
#    creating: train/F0169/MID4/
#   inflating: train/F0169/MID4/P11852_face3.jpg
#   inflating: train/F0169/MID4/P11848_face1.jpg
#   inflating: train/F0169/MID4/P11844_face1.jpg
#   inflating: train/F0169/MID4/P11851_face1.jpg
#   inflating: train/F0169/MID4/P11853_face2.jpg
#   inflating: train/F0169/MID4/P11854_face1.jpg
#   inflating: train/F0169/MID2/P11850_face1.jpg
#   inflating: train/F0169/MID2/P11848_face2.jpg
#   inflating: train/F0169/MID2/P11851_face2.jpg
#   inflating: train/F0169/MID2/P11847_face1.jpg
#   inflating: train/F0169/MID2/P11844_face2.jpg
#   inflating: train/F0169/MID2/P01817_face2.jpg
#   inflating: train/F0169/MID2/P11845_face2.jpg
#   inflating: train/F0169/MID2/P01816_face2.jpg
#   inflating: train/F0169/MID2/P11843_face2.jpg
#   inflating: train/F0169/MID2/P11846_face2.jpg
#   inflating: train/F0169/MID2/P11852_face1.jpg
#   inflating: train/F0169/MID2/P11855_face1.jpg
#   inflating: train/F0169/MID2/P11849_face1.jpg
#   inflating: train/F0169/MID1/P01816_face1.jpg
#   inflating: train/F0169/MID1/P11850_face2.jpg
#   inflating: train/F0169/MID1/P01819_face1.jpg
#   inflating: train/F0169/MID1/P11852_face2.jpg
#   inflating: train/F0169/MID1/P11843_face1.jpg
#   inflating: train/F0169/MID1/P11845_face1.jpg
#   inflating: train/F0169/MID1/P11846_face1.jpg
#   inflating: train/F0169/MID1/P11849_face2.jpg
#   inflating: train/F0169/MID1/P11847_face2.jpg
#   inflating: train/F0169/MID1/P11853_face1.jpg
#   inflating: train/F0169/MID1/P01817_face1.jpg
#   inflating: train/F0169/MID3/P01816_face5.jpg
#    creating: train/F0516/MID1/
#    creating: train/F0516/MID2/
#    creating: train/F0516/MID3/
#    creating: train/F0516/MID4/
#   inflating: train/F0516/MID4/P05435_face3.jpg
#   inflating: train/F0516/MID4/P05437_face1.jpg
#   inflating: train/F0516/MID2/P05435_face2.jpg
#   inflating: train/F0516/MID2/P05439_face1.jpg
#   inflating: train/F0516/MID2/P05438_face1.jpg
#   inflating: train/F0516/MID2/P05441_face2.jpg
#   inflating: train/F0516/MID2/P05440_face1.jpg
#   inflating: train/F0516/MID1/P05441_face1.jpg
#   inflating: train/F0516/MID1/P05437_face3.jpg
#   inflating: train/F0516/MID1/P05438_face2.jpg
#   inflating: train/F0516/MID1/P05435_face1.jpg
#   inflating: train/F0516/MID1/P05439_face2.jpg
#   inflating: train/F0516/MID3/P05437_face2.jpg
#   inflating: train/F0516/MID3/P05440_face2.jpg
#   inflating: train/F0516/MID3/P05435_face4.jpg
#    creating: train/F0843/MID1/
#    creating: train/F0843/MID2/
#    creating: train/F0843/MID3/
#    creating: train/F0843/MID4/
#    creating: train/F0843/MID5/
#   inflating: train/F0843/MID4/P08903_face2.jpg
#   inflating: train/F0843/MID5/P08910_face1.jpg
#   inflating: train/F0843/MID2/P08907_face2.jpg
#   inflating: train/F0843/MID2/P08905_face2.jpg
#   inflating: train/F0843/MID2/P08906_face3.jpg
#   inflating: train/F0843/MID2/P08909_face1.jpg
#   inflating: train/F0843/MID2/P08902_face2.jpg
#   inflating: train/F0843/MID2/P08908_face2.jpg
#   inflating: train/F0843/MID2/P08904_face3.jpg
#   inflating: train/F0843/MID1/P08902_face1.jpg
#   inflating: train/F0843/MID1/P08908_face1.jpg
#   inflating: train/F0843/MID1/P08905_face1.jpg
#   inflating: train/F0843/MID1/P08909_face2.jpg
#   inflating: train/F0843/MID1/P08907_face1.jpg
#   inflating: train/F0843/MID1/P08903_face1.jpg
#   inflating: train/F0843/MID1/P08906_face1.jpg
#   inflating: train/F0843/MID1/P08910_face2.jpg
#   inflating: train/F0843/MID1/P08904_face1.jpg
#   inflating: train/F0843/MID1/P08901_face2.jpg
#   inflating: train/F0843/MID3/P08901_face1.jpg

# %%
all_images = glob("train/*/*/*.jpg")
print("Total number of images: ", len(all_images))
print("Example of image path: ",all_images[0])
# Out:
# Total number of images:  12379
# Example of image path:  train/F0188/MID2/P02013_face1.jpg

# %% [markdown]
# # Train-Validation Split
#
# The images of families starting with "F09" are used as validation set.
#
# In the "train" variable, the training data are organized in pairs (photo1, photo2) depending on whether there is a kinship relationship between photo1 and photo2, which can be obtained from the end "train_relationship.csv" (example of train element: ('F0002 / MID1', 'F0002 / MID3 '))
#
# Total train pairs: 3066
# Total val pairs: 296
#
# Per fare ciò:
# * All images are recovered (all_images = glob("train/*/*/*.jpg")).
# * The images are splitted into train_images and val_images.
# * A dictionary is created in which each member of a family is related to his photos (a person has multiple related photos).
# * Get all the "single people" (identified by (Fxx / MIDx).
# * The pairs of people are created based on the relationships present in the "train_relationship.csv" file (using the "zip" command you can obtain the pairs (relationships.p1.values, relationships.p2.values), that is, pairs of the type (F0001 / MID1, F0001 / MID3)).
# * Finally, "train people" and "validation people" are created, always following the logic that F09xx families are used for validation.

# %%
from collections import defaultdict

#F09xx are used for validation.
val_families = "F09"

#An example of data:"train/F00002/MID1/P0001_face1.jpg"
all_images = glob("train/*/*/*.jpg")

train_images = [x for x in all_images if val_families not in x]
val_images = [x for x in all_images if val_families in x]

#Put the link of each picture under the keyword of a person such as "F0002 / MID1"
"""
Create a dictionary (train_person_to_images_map and val_person_to_images_map) in which each person (identified by "Family/Member/photo1.jpg") is related to the path of his photos (there are multiple photos for each person)
Example: {'F0452/MID2': ['train/F0452/MID2/P04774_face2.jpg', 'train/F0452/MID2/P04773_face2.jpg', 'train/F0452/MID2/P04771_face1.jpg']}
(The person 'F0452/MID2' (of the family 0452, the member MID2, has 3 faces))
"""
train_person_to_images_map = defaultdict(list)
for x in train_images:
    train_person_to_images_map[x.split("/")[-3] + "/" + x.split("/")[-2]].append(x)

val_person_to_images_map = defaultdict(list)
for x in val_images:
    val_person_to_images_map[x.split("/")[-3] + "/" + x.split("/")[-2]].append(x)

# Obtain all the "single people" (identified by "Fxxx/MIDx")
people = [x.split("/")[-3] + "/" + x.split("/")[-2] for x in all_images]
relationships = pd.read_csv("/content/drive/MyDrive/ComputerVisionProject/kinship-dataset/train_relationships.csv")

#For a List like[p1 p2], "zip" command can return a result like [(p1[0],p2[0]),(p1[1],p2[1]),...]
relationships = list(zip(relationships.p1.values, relationships.p2.values))
print("Total relationships pairs: ",len(relationships))
#filter unused relationships (from 3598 samplex to 3362)
relationships = [x for x in relationships if x[0] in people and x[1] in people]
print("Filtered relationships pairs: ",len(relationships))


train = [x for x in relationships if val_families not in x[0]]
val = [x for x in relationships if val_families in x[0]]

print("Example of train pair: ", train[0])
print("Total train pairs:", len(train))    
print("Total val pairs:", len(val))
# Out:
# Total relationships pairs:  3598
# Filtered relationships pairs:  3362
# Example of train pair:  ('F0002/MID1', 'F0002/MID3')
# Total train pairs: 3066
# Total val pairs: 296

# %% [markdown]
# # Obtain the training dataset and validation dataset
#
# This class allows you to create the dataset. To create the dataset it is necessary to have **positive examples** (people who are in relationship) and **negative examples** (people who are not in relationship).
# This class receives as input:
# 1. The folder containing the train data ("train/").
# 2. The variable that contains the pairs of people who are in a kinship relationship ("train" variable) (e.g. (train[0] = 'F0002 / MID1', 'F0002 / MID3')).
# 3. The type of transformation to be applied to the images .
#
# That are the operation we need to do:
# * Retrieve the information and the MULTIPLE paths of the first imagine of the pair (img_info='F0002/MID1') (img_path = train/F0002/MID1/*.jpg).
# * A photo of the first individual is obtained randomly among those of the paths (from train/F0002/MID1/*, we obtain train/F0002/MID1/face1.jpg).
# * Get all people who are related to first individual (each person has multiple people related to it).
# * A second person is randomly chosen from among the candidates related to first individual or randomly choosed non-related person (in order to obtain positive and negative samples).
# * If we have to choose positive example, a random person is chosen from related relationships of first person.
# * If we have to choose negative example, a random person is chosen from the dataset. If we (unforunatly) choose a person who is related to the first one, randomly choose another person.
#
# * Finally, open the two photos (with Image.open (img0_path)) and transform the images
#
#
# THIS PROCESS CAN BE OPTIMIZED BY CHOSING ALL THE TRAIN PAIRS AND THEN ADD SOME NEGATIVE SAMPLES

# %%
import random

class trainingDataset(Dataset):#Get two images and whether they are related.
    
    def __init__(self,imageFolderDataset, relationships, transform=None):
        self.imageFolderDataset = imageFolderDataset    
        self.relationships = relationships #choose either train or val dataset to use
        self.transform = transform
        
    def __getitem__(self,index):
        # For each relationship in the "train" variable, the first image comes from first row, 
        # and the second is either specially choosed related person or randomly choosed non-related person (in order to have positive and negative samples)
        img0_info = self.relationships[index][0]
        img0_path = glob("train/"+img0_info+"/*.jpg")
        img0_path = random.choice(img0_path) #chose randomically a photo of the individual
        
        # Found all candidates related to person in img0
        # candidate_relationship contains the value of self.relationship (that is the train or val variables,
        # so candidate_relationship = (img0_info, 'Fxxx/MIDx') OR ('Fxxx/MIDx', img0_info))
        candidate_relationship = [x for x in self.relationships if x[0]==img0_info or x[1]==img0_info] 

        # Randomly choose whether to use a positive (1) or a negative (0) example
        if candidate_relationship==[]: # in this case, this should never happen.
            choose_positive_example = 0
        else:
            # Choose randomicaly to have positive or negative example: 1 means related, and 0 means non-related.
            choose_positive_example = random.randint(0,1) 

        # If we have to choose positive example, we get the second person from related relationship
        if choose_positive_example==1:
            img1_info = random.choice(candidate_relationship)#choose the second person from related relationships
            # remember that candidate_relationship = (img0_info, 'Fxxx/MIDx') OR ('Fxxx/MIDx', img0_info)),
            # so img1 is the element of the tuple that is not img0_info 
            if img1_info[0] != img0_info:
                img1_info = img1_info[0]
            else:
                img1_info=img1_info[1]

            #randomly choose a img of second person
            img1_path = glob("train/"+img1_info+"/*.jpg")
            img1_path = random.choice(img1_path)

        # In case we have to choose negative sample, we get the second person randomicaly (0 means non-related)
        else:
            randChoose = True #in case the random chosen person is related to first person
            while randChoose:
                img1_path = random.choice(self.imageFolderDataset.imgs)[0]
                img1_info = img1_path.split("/")[-3] + "/" + img1_path.split("/")[-2]
                randChoose = False
                #if we (unforunatly) choose a person who is related to the first one, randomly choose another person
                for x in candidate_relationship:
                    if x[0]==img1_info or x[1]==img1_info:
                        randChoose = True
                        break

        # Now we have two images (they are related or not)
        img0 = Image.open(img0_path)
        img1 = Image.open(img1_path)
        
        # Transform images
        if self.transform is not None:
            img0 = self.transform(img0)
            img1 = self.transform(img1)
        
        # The returned data from dataloader is img=[batch_size,channels,width,length], should_get_same_class=[batch_size,label]
        return img0, img1 , choose_positive_example 
    
    def __len__(self):
        return len(self.relationships)#essential for choose the num of data in one epoch

# %% [markdown]
# ## Create the training and validation data
# Images are transformed using the following transformation:
#
# transforms.Compose([transforms.Resize((IMG_SIZE,IMG_SIZE))transforms.ToTensor()]))
#
# So, they are resized to a size of 100x100, and then they are transformed into tensors.
#
# img0 = Image.open(img0_path);  img0 = self.transform(img0))

# %%
folder_dataset = dset.ImageFolder(root='train/')
BATCH_SIZE=64
IMG_SIZE=100

#Training set and training loader
trainset = trainingDataset(imageFolderDataset=folder_dataset,
                                        relationships=train,
                                        transform=transforms.Compose([transforms.Resize((IMG_SIZE,IMG_SIZE)),
                                                                      transforms.ToTensor()
                                                                      ]))
trainloader = DataLoader(trainset,
                        shuffle=True,#whether randomly shuffle data in each epoch, but cannot let data in one batch in order.
                        num_workers=8,
                        batch_size=BATCH_SIZE)


#Validation set and Validation loader
valset = trainingDataset(imageFolderDataset=folder_dataset,
                                        relationships=val,
                                        transform=transforms.Compose([transforms.Resize((IMG_SIZE,IMG_SIZE)),
                                                                      transforms.ToTensor()
                                                                      ]))
valloader = DataLoader(valset,
                        shuffle=True,
                        num_workers=8,
                        batch_size=BATCH_SIZE)
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:566: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))

# %%
# only for visualize data in dataloader, it won't matters if you delete this block.

def imshow(img,text=None,should_save=False):#for showing the data loaded to dataloader
    npimg = img.numpy()
    plt.axis("off")
    if text:
        plt.text(75, 8, text, style='italic',fontweight='bold',
            bbox={'facecolor':'white', 'alpha':0.8, 'pad':10})
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.show()    

def show_plot(iteration,loss):# for showing loss value changed with iter
    plt.plot(iteration,loss)
    plt.show()


vis_dataloader = DataLoader(trainset,
                        shuffle=True,
                        num_workers=8,
                        batch_size=8)
dataiter = iter(vis_dataloader)


example_batch = next(dataiter)
concatenated = torch.cat((example_batch[0],example_batch[1]),0)
imshow(torchvision.utils.make_grid(concatenated))
print(example_batch[2].numpy())
# Out:
# [0 1 1 1 0 0 0 1]

# %% [markdown]
# # Siamese Network
#
# Four types of Siamese Networks are presented:
# * SiameseNetwork_Naive
# * SiameseNetwork_DenseNet
# * SiameseNetwork_VGG
# * SiameseNetwork_ResNet
#
# Process applied by all implementations:
#
# 1. Receive two images as input
# 2. Apply convolution to both (
#         output1 = self.cnn1(input1)
#         output1 = output1.view(output1.size()[0], -1)
#         output2 = self.cnn1(input2)
#         output2 = output2.view(output2.size()[0], -1))
#     )
# 3. The outputs are concatenated (torch.cat((output1, output2),1))
# 4. Give the concatenated output to the classifier

# %%
#10 epoche ci mette 2 min, 100 epoche ci mette 20 minuti circa
class SiameseNetwork_Naive(nn.Module):
    def __init__(self):
        super(SiameseNetwork_Naive, self).__init__()
        
        model = nn.Sequential(
            nn.ReflectionPad2d((1,1,1,1)),
            nn.Conv2d(3,64,kernel_size=(3,3), stride=(1,1)),
            nn.ReLU(inplace=True),
            nn.BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True),

            nn.ReflectionPad2d((1,1,1,1)),
            nn.Conv2d(64,32,kernel_size=(3,3), stride=(1,1)),
            nn.ReLU(inplace=True),
            nn.BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True),

            nn.ReflectionPad2d((1,1,1,1)),
            nn.Conv2d(32,8,kernel_size=(3,3), stride=(1,1)),
            nn.ReLU(inplace=True),
            nn.BatchNorm2d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True),
           )
        
        self.cnn1 = torch.nn.Sequential(*(list(model.children())[:-1]))


        model.classifier = nn.Sequential(
            nn.Linear(in_features=160000, out_features=500, bias=True),
            nn.Linear(in_features=500, out_features=500, bias=True),
            nn.Linear(in_features=500, out_features=2, bias=True)
        )
        self.fc = model.classifier
        
        
    def forward(self, input1, input2):
        output1 = self.cnn1(input1)
        output1 = output1.view(output1.size()[0], -1)
        output2 = self.cnn1(input2)
        output2 = output2.view(output2.size()[0], -1)
        
        output = torch.cat((output1, output2),1)
        #print(output.shape) #è l'output che deve aver il primo fc
        output = self.fc(output)
        return output

# %%
#10 epoche ci mette 6 min, 100 epoche ci mette 1 ora circa
class SiameseNetwork_DenseNet(nn.Module):
    def __init__(self):
        super(SiameseNetwork_DenseNet, self).__init__()
        
        
        model = models.densenet161(pretrained=True) 

        #Freezing tutti i layers
        for param in model.parameters():
          param.require_grad = False

        #Estrazione blocco convoluzionale
        self.cnn1 = torch.nn.Sequential(*(list(model.children())[:-1]))

        #Aggiunta nuovi layers pienamente connessi per classificazione 
        model.classifier = nn.Sequential(
            nn.Linear(39744, 460),
            nn.ReLU(),
            nn.Linear(460, 230),  
            nn.ReLU(),     
            nn.Linear(230, 2)              
        )

        self.fc = model.classifier 
        


    def forward(self, input1, input2):
        output1 = self.cnn1(input1)
        output1 = output1.view(output1.size()[0], -1)
        output2 = self.cnn1(input2)
        output2 = output2.view(output2.size()[0], -1)
        
        output = torch.cat((output1, output2),1)
        #print(output.shape) #è l'output che deve aver il primo fc
        output = self.fc(output)
        return output

# %%
#10 epoche in 4,29 min, 100 epoche in circa 45 min
class SiameseNetwork_VGG(nn.Module):
    def __init__(self):
        super(SiameseNetwork_VGG, self).__init__()
        
        model = models.vgg19(pretrained=True) #Carico VGGFace19 già allenata
        #Freezing tutti i layers
        for param in model.parameters():
          param.require_grad = False

        #Estrazione blocco convoluzionale
        self.cnn1 = torch.nn.Sequential(*(list(model.children())[:-1]))

        #Aggiungo nuovi layers pienamente connessi
        model.classifier = nn.Sequential(
            nn.Linear(50176, 460),
            nn.ReLU(),
            nn.Linear(460, 230),  
            nn.ReLU(),     
            nn.Linear(230, 2)              
        )

        self.fc = model.classifier 
        


    def forward(self, input1, input2):
        output1 = self.cnn1(input1)
        output1 = output1.view(output1.size()[0], -1)
        output2 = self.cnn1(input2)
        output2 = output2.view(output2.size()[0], -1)
        
        output = torch.cat((output1, output2),1)
        #print(output.shape) #è l'output che deve aver il primo fc
        output = self.fc(output)
        return output

# %%
class SiameseNetwork_ResNet(nn.Module):
    def __init__(self):
        super(SiameseNetwork_ResNet, self).__init__()
        
        model = models.resnet101(pretrained=True) #Carico ResNet già addestrata
        #Freezing tutti i layers
        for param in model.parameters():
          param.require_grad = False

        #Estrazione blocco convoluzionale
        self.cnn1 = torch.nn.Sequential(*(list(model.children())[:-1]))

        #Aggiungo nuovi layers pienamente connessi
        model.classifier = nn.Sequential(
            nn.Linear(4096,460),
            nn.ReLU(),
            nn.Linear(460, 230),  
            nn.ReLU(),     
            nn.Linear(230, 2)              
        )

        self.fc = model.classifier 
        


    def forward(self, input1, input2):
        output1 = self.cnn1(input1)
        output1 = output1.view(output1.size()[0], -1)
        output2 = self.cnn1(input2)
        output2 = output2.view(output2.size()[0], -1)
        
        output = torch.cat((output1, output2),1)
        #print(output.shape) #è l'output che deve aver il primo fc
        output = self.fc(output)
        return output

# %% [markdown]
# # Network creation
#
# Here you can chose the network you want by changing the Siamese Network

# %%
#Here you can chose the network you want by changing the Siamese Network
net = SiameseNetwork_ResNet().cuda()
criterion = nn.CrossEntropyLoss() # use a Classification Cross-Entropy loss
optimizer = optim.SGD(net.parameters(), lr=0.001, momentum=0.9)


print(net.eval())
# Out:
# /usr/local/lib/python3.7/dist-packages/torchvision/models/_utils.py:209: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and will be removed in 0.15, please use 'weights' instead.
#   f"The parameter '{pretrained_param}' is deprecated since 0.13 and will be removed in 0.15, "
# /usr/local/lib/python3.7/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and will be removed in 0.15. The current behavior is equivalent to passing `weights=ResNet101_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet101_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/resnet101-63fe2227.pth" to /root/.cache/torch/hub/checkpoints/resnet101-63fe2227.pth
#   0%|          | 0.00/171M [00:00<?, ?B/s]
# SiameseNetwork_ResNet(
#   (cnn1): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (4): Sequential(
#       (0): Bottleneck(
#         (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (downsample): Sequential(
#           (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): Bottleneck(
#         (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (2): Bottleneck(
#         (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#     )
#     (5): Sequential(
#       (0): Bottleneck(
#         (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (downsample): Sequential(
#           (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): Bottleneck(
#         (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (2): Bottleneck(
#         (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (3): Bottleneck(
#         (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#     )
#     (6): Sequential(
#       (0): Bottleneck(
#         (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (downsample): Sequential(
#           (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (2): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (3): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (4): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (5): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (6): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (7): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (8): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (9): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (10): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (11): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (12): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (13): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (14): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (15): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (16): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (17): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (18): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (19): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (20): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (21): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (22): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#     )
#     (7): Sequential(
#       (0): Bottleneck(
#         (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (downsample): Sequential(
#           (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): Bottleneck(
#         (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (2): Bottleneck(
#         (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#     )
#     (8): AdaptiveAvgPool2d(output_size=(1, 1))
#   )
#   (fc): Sequential(
#     (0): Linear(in_features=4096, out_features=460, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=460, out_features=230, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=230, out_features=2, bias=True)
#   )
# )

# %% [markdown]
# #TRAINING PHASE

# %%
counter = []
loss_history = [] 
iteration_number= 0

BATCH_SIZE=64
NUMBER_EPOCHS=100
epoch_accuracies = np.array([])

for epoch in range(0,NUMBER_EPOCHS):
    print("Epoch：", epoch, " start.")
    for i, data in enumerate(trainloader,0):
        img0, img1 , labels = data #img=tensor[batch_size,channels,width,length], label=tensor[batch_size,label]
        img0, img1 , labels = img0.cuda(), img1.cuda() , labels.cuda()#move to GPU

        optimizer.zero_grad()#clear the calculated grad in previous batch
        outputs = net(img0,img1)
        loss = criterion(outputs,labels)
        loss.backward()
        optimizer.step()
        if i %10 == 0 :#show changes of loss value after each 10 batches
            #print("Epoch number {}\n Current loss {}\n".format(epoch,loss.item()))
            iteration_number +=10
            counter.append(iteration_number)
            loss_history.append(loss.item())
    
    #test the network after finish each epoch, to have a brief training result.
    correct_val = 0
    total_val = 0
    with torch.no_grad(): #essential for testing!
        for data in valloader:
            img0, img1 , labels = data
            img0, img1 , labels = img0.cuda(), img1.cuda() , labels.cuda()
            outputs = net(img0,img1)
            _, predicted = torch.max(outputs.data, 1)
            total_val += labels.size(0)
            correct_val += (predicted == labels).sum().item()

    accuracy = 100 * correct_val / total_val
    epoch_accuracies = np.append(epoch_accuracies, accuracy)

    print('Accuracy of the network on the', total_val, 'val pairs in',val_families, ': %d %%' % (100 * correct_val / total_val))
    show_plot(counter,loss_history)

best_accuracy = np.amax(epoch_accuracies)
best_epoch = epoch_accuracies.argmax()
print('END TRAINING: BEST EPOCH: ', best_epoch, ' WITH ACCURACY: ', best_accuracy)
# Out:
# Epoch： 0  start.
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:566: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Accuracy of the network on the 296 val pairs in F09 : 62 %
# Epoch： 1  start.
# Accuracy of the network on the 296 val pairs in F09 : 57 %
# Epoch： 2  start.
# Accuracy of the network on the 296 val pairs in F09 : 54 %
# Epoch： 3  start.
# Accuracy of the network on the 296 val pairs in F09 : 56 %
# Epoch： 4  start.
# Accuracy of the network on the 296 val pairs in F09 : 52 %
# Epoch： 5  start.
# Accuracy of the network on the 296 val pairs in F09 : 59 %
# Epoch： 6  start.
# Accuracy of the network on the 296 val pairs in F09 : 54 %
# Epoch： 7  start.
# Accuracy of the network on the 296 val pairs in F09 : 58 %
# Epoch： 8  start.
# Accuracy of the network on the 296 val pairs in F09 : 55 %
# Epoch： 9  start.
# Accuracy of the network on the 296 val pairs in F09 : 62 %
# Epoch： 10  start.
# Accuracy of the network on the 296 val pairs in F09 : 59 %
# Epoch： 11  start.
# Accuracy of the network on the 296 val pairs in F09 : 59 %
# Epoch： 12  start.
# Accuracy of the network on the 296 val pairs in F09 : 65 %
# Epoch： 13  start.
# Accuracy of the network on the 296 val pairs in F09 : 59 %
# Epoch： 14  start.
# Accuracy of the network on the 296 val pairs in F09 : 60 %
# Epoch： 15  start.
# Accuracy of the network on the 296 val pairs in F09 : 64 %
# Epoch： 16  start.
# Accuracy of the network on the 296 val pairs in F09 : 65 %
# Epoch： 17  start.
# Accuracy of the network on the 296 val pairs in F09 : 63 %
# Epoch： 18  start.
# Accuracy of the network on the 296 val pairs in F09 : 68 %
# Epoch： 19  start.
# Accuracy of the network on the 296 val pairs in F09 : 61 %
# Epoch： 20  start.
# Accuracy of the network on the 296 val pairs in F09 : 61 %
# Epoch： 21  start.
# Accuracy of the network on the 296 val pairs in F09 : 66 %
# Epoch： 22  start.
# Accuracy of the network on the 296 val pairs in F09 : 60 %
# Epoch： 23  start.
# Accuracy of the network on the 296 val pairs in F09 : 64 %
# Epoch： 24  start.
# Accuracy of the network on the 296 val pairs in F09 : 65 %
# Epoch： 25  start.
# Accuracy of the network on the 296 val pairs in F09 : 67 %
# Epoch： 26  start.
# Accuracy of the network on the 296 val pairs in F09 : 66 %
# Epoch： 27  start.
# Accuracy of the network on the 296 val pairs in F09 : 60 %
# Epoch： 28  start.
# Accuracy of the network on the 296 val pairs in F09 : 62 %
# Epoch： 29  start.
# Accuracy of the network on the 296 val pairs in F09 : 63 %
# Epoch： 30  start.
# Accuracy of the network on the 296 val pairs in F09 : 60 %
# Epoch： 31  start.
# Accuracy of the network on the 296 val pairs in F09 : 60 %
# Epoch： 32  start.
# Accuracy of the network on the 296 val pairs in F09 : 66 %
# Epoch： 33  start.
# Accuracy of the network on the 296 val pairs in F09 : 66 %
# Epoch： 34  start.
# Accuracy of the network on the 296 val pairs in F09 : 67 %
# Epoch： 35  start.
# Accuracy of the network on the 296 val pairs in F09 : 60 %
# Epoch： 36  start.
# Accuracy of the network on the 296 val pairs in F09 : 62 %
# Epoch： 37  start.
# Accuracy of the network on the 296 val pairs in F09 : 64 %
# Epoch： 38  start.
# Accuracy of the network on the 296 val pairs in F09 : 67 %
# Epoch： 39  start.
# Accuracy of the network on the 296 val pairs in F09 : 64 %
# Epoch： 40  start.
# Accuracy of the network on the 296 val pairs in F09 : 68 %
# Epoch： 41  start.
# Accuracy of the network on the 296 val pairs in F09 : 67 %
# Epoch： 42  start.
# Accuracy of the network on the 296 val pairs in F09 : 63 %
# Epoch： 43  start.
# Accuracy of the network on the 296 val pairs in F09 : 65 %
# Epoch： 44  start.
# Accuracy of the network on the 296 val pairs in F09 : 64 %
# Epoch： 45  start.
# Accuracy of the network on the 296 val pairs in F09 : 67 %
# Epoch： 46  start.
# Accuracy of the network on the 296 val pairs in F09 : 72 %
# Epoch： 47  start.
# Accuracy of the network on the 296 val pairs in F09 : 68 %
# Epoch： 48  start.
# Accuracy of the network on the 296 val pairs in F09 : 63 %
# Epoch： 49  start.
# Accuracy of the network on the 296 val pairs in F09 : 63 %
# Epoch： 50  start.
# Accuracy of the network on the 296 val pairs in F09 : 69 %
# Epoch： 51  start.
# Accuracy of the network on the 296 val pairs in F09 : 69 %
# Epoch： 52  start.
# Accuracy of the network on the 296 val pairs in F09 : 70 %
# Epoch： 53  start.
# Accuracy of the network on the 296 val pairs in F09 : 66 %
# Epoch： 54  start.
# Accuracy of the network on the 296 val pairs in F09 : 67 %
# Epoch： 55  start.
# Accuracy of the network on the 296 val pairs in F09 : 68 %
# Epoch： 56  start.
# Accuracy of the network on the 296 val pairs in F09 : 65 %
# Epoch： 57  start.
# Accuracy of the network on the 296 val pairs in F09 : 65 %
# Epoch： 58  start.
# Accuracy of the network on the 296 val pairs in F09 : 62 %
# Epoch： 59  start.
# Accuracy of the network on the 296 val pairs in F09 : 62 %
# Epoch： 60  start.
# Accuracy of the network on the 296 val pairs in F09 : 60 %
# Epoch： 61  start.
# Accuracy of the network on the 296 val pairs in F09 : 68 %
# Epoch： 62  start.
# Accuracy of the network on the 296 val pairs in F09 : 63 %
# Epoch： 63  start.
# Accuracy of the network on the 296 val pairs in F09 : 68 %
# Epoch： 64  start.
# Accuracy of the network on the 296 val pairs in F09 : 59 %
# Epoch： 65  start.
# Accuracy of the network on the 296 val pairs in F09 : 68 %
# Epoch： 66  start.
# Accuracy of the network on the 296 val pairs in F09 : 64 %
# Epoch： 67  start.
# Accuracy of the network on the 296 val pairs in F09 : 64 %
# Epoch： 68  start.
# Accuracy of the network on the 296 val pairs in F09 : 65 %
# Epoch： 69  start.
# Accuracy of the network on the 296 val pairs in F09 : 67 %
# Epoch： 70  start.
# Accuracy of the network on the 296 val pairs in F09 : 60 %
# Epoch： 71  start.
# Accuracy of the network on the 296 val pairs in F09 : 65 %
# Epoch： 72  start.
# Accuracy of the network on the 296 val pairs in F09 : 65 %
# Epoch： 73  start.
# Accuracy of the network on the 296 val pairs in F09 : 63 %
# Epoch： 74  start.
# Accuracy of the network on the 296 val pairs in F09 : 65 %
# Epoch： 75  start.
# Accuracy of the network on the 296 val pairs in F09 : 72 %
# Epoch： 76  start.
# Accuracy of the network on the 296 val pairs in F09 : 69 %
# Epoch： 77  start.
# Accuracy of the network on the 296 val pairs in F09 : 63 %
# Epoch： 78  start.
# Accuracy of the network on the 296 val pairs in F09 : 65 %
# Epoch： 79  start.
# Accuracy of the network on the 296 val pairs in F09 : 69 %
# Epoch： 80  start.
# Accuracy of the network on the 296 val pairs in F09 : 68 %
# Epoch： 81  start.
# Accuracy of the network on the 296 val pairs in F09 : 67 %
# Epoch： 82  start.
# Accuracy of the network on the 296 val pairs in F09 : 66 %
# Epoch： 83  start.
# Accuracy of the network on the 296 val pairs in F09 : 66 %
# Epoch： 84  start.
# Accuracy of the network on the 296 val pairs in F09 : 65 %
# Epoch： 85  start.
# Accuracy of the network on the 296 val pairs in F09 : 66 %
# Epoch： 86  start.
# Accuracy of the network on the 296 val pairs in F09 : 61 %
# Epoch： 87  start.
# Accuracy of the network on the 296 val pairs in F09 : 61 %
# Epoch： 88  start.
# Accuracy of the network on the 296 val pairs in F09 : 67 %
# Epoch： 89  start.
# Accuracy of the network on the 296 val pairs in F09 : 62 %
# Epoch： 90  start.
# Accuracy of the network on the 296 val pairs in F09 : 63 %
# Epoch： 91  start.
# Accuracy of the network on the 296 val pairs in F09 : 62 %
# Epoch： 92  start.
# Accuracy of the network on the 296 val pairs in F09 : 62 %
# Epoch： 93  start.
# Accuracy of the network on the 296 val pairs in F09 : 67 %
# Epoch： 94  start.
# Accuracy of the network on the 296 val pairs in F09 : 65 %
# Epoch： 95  start.
# Accuracy of the network on the 296 val pairs in F09 : 66 %
# Epoch： 96  start.
# Accuracy of the network on the 296 val pairs in F09 : 57 %
# Epoch： 97  start.
# Accuracy of the network on the 296 val pairs in F09 : 65 %
# Epoch： 98  start.
# Accuracy of the network on the 296 val pairs in F09 : 63 %
# Epoch： 99  start.
# Accuracy of the network on the 296 val pairs in F09 : 65 %
# END TRAINING: BEST EPOCH:  75  WITH ACCURACY:  72.63513513513513

# %% [markdown]
# # TESTING

# %%
# Unzip the test faces in the (local) "test" folder
# !unzip "/content/drive/MyDrive/ComputerVisionProject/kinship-dataset/test.zip" -d "test"
# Out:
# Output streaming troncato alle ultime 5000 righe.
#   inflating: test/face04688.jpg
#   inflating: test/face03972.jpg
#   inflating: test/face02593.jpg
#   inflating: test/face00836.jpg
#   inflating: test/face05284.jpg
#   inflating: test/face03261.jpg
#   inflating: test/face00582.jpg
#   inflating: test/face02696.jpg
#   inflating: test/face05325.jpg
#   inflating: test/face04973.jpg
#   inflating: test/face02902.jpg
#   inflating: test/face06245.jpg
#   inflating: test/face00645.jpg
#   inflating: test/face03284.jpg
#   inflating: test/face00188.jpg
#   inflating: test/face05490.jpg
#   inflating: test/face01683.jpg
#   inflating: test/face05566.jpg
#   inflating: test/face03288.jpg
#   inflating: test/face00045.jpg
#   inflating: test/face06050.jpg
#   inflating: test/face02871.jpg
#   inflating: test/face04507.jpg
#   inflating: test/face01597.jpg
#   inflating: test/face03175.jpg
#   inflating: test/face01910.jpg
#   inflating: test/face04046.jpg
#   inflating: test/face04884.jpg
#   inflating: test/face05458.jpg
#   inflating: test/face01075.jpg
#   inflating: test/face04616.jpg
#   inflating: test/face03468.jpg
#   inflating: test/face04340.jpg
#   inflating: test/face01466.jpg
#   inflating: test/face04988.jpg
#   inflating: test/face04774.jpg
#   inflating: test/face03461.jpg
#   inflating: test/face04626.jpg
#   inflating: test/face00478.jpg
#   inflating: test/face02623.jpg
#   inflating: test/face02450.jpg
#   inflating: test/face04148.jpg
#   inflating: test/face04704.jpg
#   inflating: test/face03834.jpg
#   inflating: test/face01685.jpg
#   inflating: test/face06028.jpg
#   inflating: test/face03897.jpg
#   inflating: test/face05488.jpg
#   inflating: test/face01698.jpg
#   inflating: test/face06219.jpg
#   inflating: test/face02001.jpg
#   inflating: test/face01824.jpg
#   inflating: test/face01882.jpg
#   inflating: test/face02515.jpg
#   inflating: test/face02474.jpg
#   inflating: test/face00055.jpg
#   inflating: test/face01164.jpg
#   inflating: test/face00517.jpg
#   inflating: test/face00065.jpg
#   inflating: test/face03639.jpg
#   inflating: test/face05520.jpg
#   inflating: test/face04179.jpg
#   inflating: test/face01895.jpg
#   inflating: test/face03662.jpg
#   inflating: test/face03369.jpg
#   inflating: test/face03913.jpg
#   inflating: test/face04620.jpg
#   inflating: test/face04617.jpg
#   inflating: test/face01190.jpg
#   inflating: test/face04723.jpg
#   inflating: test/face05754.jpg
#   inflating: test/face01593.jpg
#   inflating: test/face02337.jpg
#   inflating: test/face04250.jpg
#   inflating: test/face05681.jpg
#   inflating: test/face00394.jpg
#   inflating: test/face03641.jpg
#   inflating: test/face04113.jpg
#   inflating: test/face03386.jpg
#   inflating: test/face02658.jpg
#   inflating: test/face02858.jpg
#   inflating: test/face06235.jpg
#   inflating: test/face03174.jpg
#   inflating: test/face04848.jpg
#   inflating: test/face01942.jpg
#   inflating: test/face04376.jpg
#   inflating: test/face03671.jpg
#   inflating: test/face02191.jpg
#   inflating: test/face06244.jpg
#   inflating: test/face00620.jpg
#   inflating: test/face05393.jpg
#   inflating: test/face01180.jpg
#   inflating: test/face01126.jpg
#   inflating: test/face00890.jpg
#   inflating: test/face01088.jpg
#   inflating: test/face02468.jpg
#   inflating: test/face00563.jpg
#   inflating: test/face02989.jpg
#   inflating: test/face01358.jpg
#   inflating: test/face04554.jpg
#   inflating: test/face02615.jpg
#   inflating: test/face02349.jpg
#   inflating: test/face05812.jpg
#   inflating: test/face00474.jpg
#   inflating: test/face01656.jpg
#   inflating: test/face01134.jpg
#   inflating: test/face02072.jpg
#   inflating: test/face04162.jpg
#   inflating: test/face00587.jpg
#   inflating: test/face02552.jpg
#   inflating: test/face01937.jpg
#   inflating: test/face05521.jpg
#   inflating: test/face04813.jpg
#   inflating: test/face05763.jpg
#   inflating: test/face02802.jpg
#   inflating: test/face03892.jpg
#   inflating: test/face03813.jpg
#   inflating: test/face00957.jpg
#   inflating: test/face03389.jpg
#   inflating: test/face02881.jpg
#   inflating: test/face03982.jpg
#   inflating: test/face02887.jpg
#   inflating: test/face04122.jpg
#   inflating: test/face02429.jpg
#   inflating: test/face01145.jpg
#   inflating: test/face05053.jpg
#   inflating: test/face01784.jpg
#   inflating: test/face04876.jpg
#   inflating: test/face00063.jpg
#   inflating: test/face04382.jpg
#   inflating: test/face04647.jpg
#   inflating: test/face01627.jpg
#   inflating: test/face02667.jpg
#   inflating: test/face01809.jpg
#   inflating: test/face04418.jpg
#   inflating: test/face05936.jpg
#   inflating: test/face03644.jpg
#   inflating: test/face04297.jpg
#   inflating: test/face02333.jpg
#   inflating: test/face01102.jpg
#   inflating: test/face05735.jpg
#   inflating: test/face03645.jpg
#   inflating: test/face05538.jpg
#   inflating: test/face04956.jpg
#   inflating: test/face01666.jpg
#   inflating: test/face05272.jpg
#   inflating: test/face05513.jpg
#   inflating: test/face04506.jpg
#   inflating: test/face02111.jpg
#   inflating: test/face05730.jpg
#   inflating: test/face03392.jpg
#   inflating: test/face00301.jpg
#   inflating: test/face01375.jpg
#   inflating: test/face00747.jpg
#   inflating: test/face05661.jpg
#   inflating: test/face00094.jpg
#   inflating: test/face02430.jpg
#   inflating: test/face05560.jpg
#   inflating: test/face00515.jpg
#   inflating: test/face02947.jpg
#   inflating: test/face01500.jpg
#   inflating: test/face04067.jpg
#   inflating: test/face04736.jpg
#   inflating: test/face03422.jpg
#   inflating: test/face00991.jpg
#   inflating: test/face01226.jpg
#   inflating: test/face02154.jpg
#   inflating: test/face00375.jpg
#   inflating: test/face02774.jpg
#   inflating: test/face00668.jpg
#   inflating: test/face02614.jpg
#   inflating: test/face05780.jpg
#   inflating: test/face05516.jpg
#   inflating: test/face04891.jpg
#   inflating: test/face01769.jpg
#   inflating: test/face00309.jpg
#   inflating: test/face04411.jpg
#   inflating: test/face00057.jpg
#   inflating: test/face05305.jpg
#   inflating: test/face04862.jpg
#   inflating: test/face03703.jpg
#   inflating: test/face02027.jpg
#   inflating: test/face02350.jpg
#   inflating: test/face00863.jpg
#   inflating: test/face04330.jpg
#   inflating: test/face04763.jpg
#   inflating: test/face00674.jpg
#   inflating: test/face00891.jpg
#   inflating: test/face05456.jpg
#   inflating: test/face04348.jpg
#   inflating: test/face00101.jpg
#   inflating: test/face03171.jpg
#   inflating: test/face04363.jpg
#   inflating: test/face06152.jpg
#   inflating: test/face03091.jpg
#   inflating: test/face01570.jpg
#   inflating: test/face04834.jpg
#   inflating: test/face04975.jpg
#   inflating: test/face06236.jpg
#   inflating: test/face00155.jpg
#   inflating: test/face00648.jpg
#   inflating: test/face05257.jpg
#   inflating: test/face02619.jpg
#   inflating: test/face02918.jpg
#   inflating: test/face06063.jpg
#   inflating: test/face01024.jpg
#   inflating: test/face06061.jpg
#   inflating: test/face06047.jpg
#   inflating: test/face00211.jpg
#   inflating: test/face05447.jpg
#   inflating: test/face02318.jpg
#   inflating: test/face03214.jpg
#   inflating: test/face00008.jpg
#   inflating: test/face02709.jpg
#   inflating: test/face01114.jpg
#   inflating: test/face03496.jpg
#   inflating: test/face01655.jpg
#   inflating: test/face03613.jpg
#   inflating: test/face02903.jpg
#   inflating: test/face01612.jpg
#   inflating: test/face03665.jpg
#   inflating: test/face05186.jpg
#   inflating: test/face05100.jpg
#   inflating: test/face03539.jpg
#   inflating: test/face00614.jpg
#   inflating: test/face00806.jpg
#   inflating: test/face01428.jpg
#   inflating: test/face06258.jpg
#   inflating: test/face02683.jpg
#   inflating: test/face02262.jpg
#   inflating: test/face02830.jpg
#   inflating: test/face01307.jpg
#   inflating: test/face03853.jpg
#   inflating: test/face04227.jpg
#   inflating: test/face00637.jpg
#   inflating: test/face06017.jpg
#   inflating: test/face01048.jpg
#   inflating: test/face03336.jpg
#   inflating: test/face03234.jpg
#   inflating: test/face02883.jpg
#   inflating: test/face01341.jpg
#   inflating: test/face01060.jpg
#   inflating: test/face03608.jpg
#   inflating: test/face05090.jpg
#   inflating: test/face01843.jpg
#   inflating: test/face04645.jpg
#   inflating: test/face03952.jpg
#   inflating: test/face03378.jpg
#   inflating: test/face03177.jpg
#   inflating: test/face04828.jpg
#   inflating: test/face02353.jpg
#   inflating: test/face03787.jpg
#   inflating: test/face04865.jpg
#   inflating: test/face01094.jpg
#   inflating: test/face04541.jpg
#   inflating: test/face01652.jpg
#   inflating: test/face00465.jpg
#   inflating: test/face02044.jpg
#   inflating: test/face01150.jpg
#   inflating: test/face02284.jpg
#   inflating: test/face03264.jpg
#   inflating: test/face06259.jpg
#   inflating: test/face01884.jpg
#   inflating: test/face05388.jpg
#   inflating: test/face03293.jpg
#   inflating: test/face06068.jpg
#   inflating: test/face00075.jpg
#   inflating: test/face06154.jpg
#   inflating: test/face01828.jpg
#   inflating: test/face02782.jpg
#   inflating: test/face04394.jpg
#   inflating: test/face05322.jpg
#   inflating: test/face04213.jpg
#   inflating: test/face01950.jpg
#   inflating: test/face03036.jpg
#   inflating: test/face02788.jpg
#   inflating: test/face00964.jpg
#   inflating: test/face01108.jpg
#   inflating: test/face05782.jpg
#   inflating: test/face01813.jpg
#   inflating: test/face04023.jpg
#   inflating: test/face04732.jpg
#   inflating: test/face05537.jpg
#   inflating: test/face06156.jpg
#   inflating: test/face03616.jpg
#   inflating: test/face00464.jpg
#   inflating: test/face01267.jpg
#   inflating: test/face01725.jpg
#   inflating: test/face02422.jpg
#   inflating: test/face00364.jpg
#   inflating: test/face02456.jpg
#   inflating: test/face01232.jpg
#   inflating: test/face00864.jpg
#   inflating: test/face00667.jpg
#   inflating: test/face01383.jpg
#   inflating: test/face03916.jpg
#   inflating: test/face00683.jpg
#   inflating: test/face05884.jpg
#   inflating: test/face03495.jpg
#   inflating: test/face05822.jpg
#   inflating: test/face04335.jpg
#   inflating: test/face01141.jpg
#   inflating: test/face00722.jpg
#   inflating: test/face05012.jpg
#   inflating: test/face05854.jpg
#   inflating: test/face01624.jpg
#   inflating: test/face03749.jpg
#   inflating: test/face02385.jpg
#   inflating: test/face06039.jpg
#   inflating: test/face01157.jpg
#   inflating: test/face01366.jpg
#   inflating: test/face02749.jpg
#   inflating: test/face02165.jpg
#   inflating: test/face04257.jpg
#   inflating: test/face02250.jpg
#   inflating: test/face02189.jpg
#   inflating: test/face01919.jpg
#   inflating: test/face04555.jpg
#   inflating: test/face02444.jpg
#   inflating: test/face01569.jpg
#   inflating: test/face05598.jpg
#   inflating: test/face04212.jpg
#   inflating: test/face00415.jpg
#   inflating: test/face05294.jpg
#   inflating: test/face06183.jpg
#   inflating: test/face02344.jpg
#   inflating: test/face03522.jpg
#   inflating: test/face06197.jpg
#   inflating: test/face01608.jpg
#   inflating: test/face00230.jpg
#   inflating: test/face01907.jpg
#   inflating: test/face02239.jpg
#   inflating: test/face03478.jpg
#   inflating: test/face05440.jpg
#   inflating: test/face04882.jpg
#   inflating: test/face01568.jpg
#   inflating: test/face01576.jpg
#   inflating: test/face03006.jpg
#   inflating: test/face02877.jpg
#   inflating: test/face02633.jpg
#   inflating: test/face04442.jpg
#   inflating: test/face04578.jpg
#   inflating: test/face03893.jpg
#   inflating: test/face06087.jpg
#   inflating: test/face04918.jpg
#   inflating: test/face06089.jpg
#   inflating: test/face03396.jpg
#   inflating: test/face02374.jpg
#   inflating: test/face02079.jpg
#   inflating: test/face02073.jpg
#   inflating: test/face02791.jpg
#   inflating: test/face03263.jpg
#   inflating: test/face03849.jpg
#   inflating: test/face04075.jpg
#   inflating: test/face03425.jpg
#   inflating: test/face04959.jpg
#   inflating: test/face03298.jpg
#   inflating: test/face04758.jpg
#   inflating: test/face03098.jpg
#   inflating: test/face00703.jpg
#   inflating: test/face03868.jpg
#   inflating: test/face04640.jpg
#   inflating: test/face04164.jpg
#   inflating: test/face05947.jpg
#   inflating: test/face04539.jpg
#   inflating: test/face03043.jpg
#   inflating: test/face02118.jpg
#   inflating: test/face05983.jpg
#   inflating: test/face01262.jpg
#   inflating: test/face03434.jpg
#   inflating: test/face00503.jpg
#   inflating: test/face04474.jpg
#   inflating: test/face00714.jpg
#   inflating: test/face01520.jpg
#   inflating: test/face03544.jpg
#   inflating: test/face02424.jpg
#   inflating: test/face00435.jpg
#   inflating: test/face00386.jpg
#   inflating: test/face05595.jpg
#   inflating: test/face01458.jpg
#   inflating: test/face00631.jpg
#   inflating: test/face04119.jpg
#   inflating: test/face05929.jpg
#   inflating: test/face01109.jpg
#   inflating: test/face06234.jpg
#   inflating: test/face04967.jpg
#   inflating: test/face01435.jpg
#   inflating: test/face01279.jpg
#   inflating: test/face03443.jpg
#   inflating: test/face01951.jpg
#   inflating: test/face02628.jpg
#   inflating: test/face04047.jpg
#   inflating: test/face01002.jpg
#   inflating: test/face04138.jpg
#   inflating: test/face00749.jpg
#   inflating: test/face05980.jpg
#   inflating: test/face04019.jpg
#   inflating: test/face00889.jpg
#   inflating: test/face00612.jpg
#   inflating: test/face03348.jpg
#   inflating: test/face05710.jpg
#   inflating: test/face00178.jpg
#   inflating: test/face04001.jpg
#   inflating: test/face02214.jpg
#   inflating: test/face06242.jpg
#   inflating: test/face00198.jpg
#   inflating: test/face04323.jpg
#   inflating: test/face00910.jpg
#   inflating: test/face00848.jpg
#   inflating: test/face05965.jpg
#   inflating: test/face02466.jpg
#   inflating: test/face02050.jpg
#   inflating: test/face05479.jpg
#   inflating: test/face03271.jpg
#   inflating: test/face01001.jpg
#   inflating: test/face04036.jpg
#   inflating: test/face00753.jpg
#   inflating: test/face02875.jpg
#   inflating: test/face05574.jpg
#   inflating: test/face00661.jpg
#   inflating: test/face00690.jpg
#   inflating: test/face04929.jpg
#   inflating: test/face04383.jpg
#   inflating: test/face02962.jpg
#   inflating: test/face05013.jpg
#   inflating: test/face03575.jpg
#   inflating: test/face05242.jpg
#   inflating: test/face01299.jpg
#   inflating: test/face03745.jpg
#   inflating: test/face01934.jpg
#   inflating: test/face03869.jpg
#   inflating: test/face03711.jpg
#   inflating: test/face03914.jpg
#   inflating: test/face05514.jpg
#   inflating: test/face00420.jpg
#   inflating: test/face03139.jpg
#   inflating: test/face01855.jpg
#   inflating: test/face02259.jpg
#   inflating: test/face04709.jpg
#   inflating: test/face01712.jpg
#   inflating: test/face04460.jpg
#   inflating: test/face04743.jpg
#   inflating: test/face05442.jpg
#   inflating: test/face01278.jpg
#   inflating: test/face05690.jpg
#   inflating: test/face01909.jpg
#   inflating: test/face00528.jpg
#   inflating: test/face03280.jpg
#   inflating: test/face04143.jpg
#   inflating: test/face06091.jpg
#   inflating: test/face04114.jpg
#   inflating: test/face04714.jpg
#   inflating: test/face05206.jpg
#   inflating: test/face02267.jpg
#   inflating: test/face05280.jpg
#   inflating: test/face01330.jpg
#   inflating: test/face02387.jpg
#   inflating: test/face06078.jpg
#   inflating: test/face02172.jpg
#   inflating: test/face01130.jpg
#   inflating: test/face02406.jpg
#   inflating: test/face03691.jpg
#   inflating: test/face01791.jpg
#   inflating: test/face05941.jpg
#   inflating: test/face02049.jpg
#   inflating: test/face03523.jpg
#   inflating: test/face02483.jpg
#   inflating: test/face04544.jpg
#   inflating: test/face01983.jpg
#   inflating: test/face04830.jpg
#   inflating: test/face01792.jpg
#   inflating: test/face06169.jpg
#   inflating: test/face02434.jpg
#   inflating: test/face00931.jpg
#   inflating: test/face06221.jpg
#   inflating: test/face05839.jpg
#   inflating: test/face05119.jpg
#   inflating: test/face04029.jpg
#   inflating: test/face02553.jpg
#   inflating: test/face01718.jpg
#   inflating: test/face01073.jpg
#   inflating: test/face02763.jpg
#   inflating: test/face01507.jpg
#   inflating: test/face03860.jpg
#   inflating: test/face04721.jpg
#   inflating: test/face05349.jpg
#   inflating: test/face01637.jpg
#   inflating: test/face00664.jpg
#   inflating: test/face04566.jpg
#   inflating: test/face04583.jpg
#   inflating: test/face04130.jpg
#   inflating: test/face05005.jpg
#   inflating: test/face00518.jpg
#   inflating: test/face03248.jpg
#   inflating: test/face05150.jpg
#   inflating: test/face03527.jpg
#   inflating: test/face02305.jpg
#   inflating: test/face02287.jpg
#   inflating: test/face00300.jpg
#   inflating: test/face01127.jpg
#   inflating: test/face04231.jpg
#   inflating: test/face03555.jpg
#   inflating: test/face03305.jpg
#   inflating: test/face00086.jpg
#   inflating: test/face04618.jpg
#   inflating: test/face03182.jpg
#   inflating: test/face03123.jpg
#   inflating: test/face05042.jpg
#   inflating: test/face01583.jpg
#   inflating: test/face01286.jpg
#   inflating: test/face06118.jpg
#   inflating: test/face05070.jpg
#   inflating: test/face02316.jpg
#   inflating: test/face04281.jpg
#   inflating: test/face05443.jpg
#   inflating: test/face00093.jpg
#   inflating: test/face05926.jpg
#   inflating: test/face01797.jpg
#   inflating: test/face01093.jpg
#   inflating: test/face05460.jpg
#   inflating: test/face00001.jpg
#   inflating: test/face02411.jpg
#   inflating: test/face02217.jpg
#   inflating: test/face00096.jpg
#   inflating: test/face00590.jpg
#   inflating: test/face03202.jpg
#   inflating: test/face03775.jpg
#   inflating: test/face02051.jpg
#   inflating: test/face03852.jpg
#   inflating: test/face01837.jpg
#   inflating: test/face03519.jpg
#   inflating: test/face05669.jpg
#   inflating: test/face03955.jpg
#   inflating: test/face00130.jpg
#   inflating: test/face00577.jpg
#   inflating: test/face00207.jpg
#   inflating: test/face06163.jpg
#   inflating: test/face00758.jpg
#   inflating: test/face06149.jpg
#   inflating: test/face04696.jpg
#   inflating: test/face01271.jpg
#   inflating: test/face01045.jpg
#   inflating: test/face05437.jpg
#   inflating: test/face03857.jpg
#   inflating: test/face00892.jpg
#   inflating: test/face02168.jpg
#   inflating: test/face05792.jpg
#   inflating: test/face02864.jpg
#   inflating: test/face05659.jpg
#   inflating: test/face02457.jpg
#   inflating: test/face00143.jpg
#   inflating: test/face01494.jpg
#   inflating: test/face06117.jpg
#   inflating: test/face06141.jpg
#   inflating: test/face05476.jpg
#   inflating: test/face03176.jpg
#   inflating: test/face04757.jpg
#   inflating: test/face02462.jpg
#   inflating: test/face05052.jpg
#   inflating: test/face05224.jpg
#   inflating: test/face05869.jpg
#   inflating: test/face05431.jpg
#   inflating: test/face00815.jpg
#   inflating: test/face04410.jpg
#   inflating: test/face01814.jpg
#   inflating: test/face03648.jpg
#   inflating: test/face03804.jpg
#   inflating: test/face02882.jpg
#   inflating: test/face02898.jpg
#   inflating: test/face05011.jpg
#   inflating: test/face00651.jpg
#   inflating: test/face05201.jpg
#   inflating: test/face03224.jpg
#   inflating: test/face01553.jpg
#   inflating: test/face04013.jpg
#   inflating: test/face04603.jpg
#   inflating: test/face03710.jpg
#   inflating: test/face02960.jpg
#   inflating: test/face03445.jpg
#   inflating: test/face01273.jpg
#   inflating: test/face05290.jpg
#   inflating: test/face01707.jpg
#   inflating: test/face00610.jpg
#   inflating: test/face00990.jpg
#   inflating: test/face05902.jpg
#   inflating: test/face02372.jpg
#   inflating: test/face00734.jpg
#   inflating: test/face04879.jpg
#   inflating: test/face01167.jpg
#   inflating: test/face01971.jpg
#   inflating: test/face03697.jpg
#   inflating: test/face05000.jpg
#   inflating: test/face02768.jpg
#   inflating: test/face01061.jpg
#   inflating: test/face03409.jpg
#   inflating: test/face01425.jpg
#   inflating: test/face02974.jpg
#   inflating: test/face05562.jpg
#   inflating: test/face03286.jpg
#   inflating: test/face05029.jpg
#   inflating: test/face01892.jpg
#   inflating: test/face03455.jpg
#   inflating: test/face03093.jpg
#   inflating: test/face06064.jpg
#   inflating: test/face05955.jpg
#   inflating: test/face02899.jpg
#   inflating: test/face02277.jpg
#   inflating: test/face05663.jpg
#   inflating: test/face05939.jpg
#   inflating: test/face01879.jpg
#   inflating: test/face00172.jpg
#   inflating: test/face00352.jpg
#   inflating: test/face04788.jpg
#   inflating: test/face03295.jpg
#   inflating: test/face06170.jpg
#   inflating: test/face01342.jpg
#   inflating: test/face05995.jpg
#   inflating: test/face00224.jpg
#   inflating: test/face03007.jpg
#   inflating: test/face06082.jpg
#   inflating: test/face05810.jpg
#   inflating: test/face01692.jpg
#   inflating: test/face01581.jpg
#   inflating: test/face05239.jpg
#   inflating: test/face04756.jpg
#   inflating: test/face01380.jpg
#   inflating: test/face05277.jpg
#   inflating: test/face05773.jpg
#   inflating: test/face01257.jpg
#   inflating: test/face06190.jpg
#   inflating: test/face03138.jpg
#   inflating: test/face04886.jpg
#   inflating: test/face04097.jpg
#   inflating: test/face05195.jpg
#   inflating: test/face01432.jpg
#   inflating: test/face00829.jpg
#   inflating: test/face03929.jpg
#   inflating: test/face02437.jpg
#   inflating: test/face04175.jpg
#   inflating: test/face01522.jpg
#   inflating: test/face06227.jpg
#   inflating: test/face00659.jpg
#   inflating: test/face02806.jpg
#   inflating: test/face03746.jpg
#   inflating: test/face05898.jpg
#   inflating: test/face03161.jpg
#   inflating: test/face02019.jpg
#   inflating: test/face01292.jpg
#   inflating: test/face04081.jpg
#   inflating: test/face00176.jpg
#   inflating: test/face03206.jpg
#   inflating: test/face04946.jpg
#   inflating: test/face02740.jpg
#   inflating: test/face02463.jpg
#   inflating: test/face01200.jpg
#   inflating: test/face01925.jpg
#   inflating: test/face05684.jpg
#   inflating: test/face04278.jpg
#   inflating: test/face00119.jpg
#   inflating: test/face04793.jpg
#   inflating: test/face02550.jpg
#   inflating: test/face03918.jpg
#   inflating: test/face03308.jpg
#   inflating: test/face03076.jpg
#   inflating: test/face01720.jpg
#   inflating: test/face00629.jpg
#   inflating: test/face00699.jpg
#   inflating: test/face05925.jpg
#   inflating: test/face00968.jpg
#   inflating: test/face05786.jpg
#   inflating: test/face06238.jpg
#   inflating: test/face02293.jpg
#   inflating: test/face00099.jpg
#   inflating: test/face02109.jpg
#   inflating: test/face02592.jpg
#   inflating: test/face04802.jpg
#   inflating: test/face01771.jpg
#   inflating: test/face02279.jpg
#   inflating: test/face00428.jpg
#   inflating: test/face02252.jpg
#   inflating: test/face04079.jpg
#   inflating: test/face02795.jpg
#   inflating: test/face02953.jpg
#   inflating: test/face05808.jpg
#   inflating: test/face01605.jpg
#   inflating: test/face02289.jpg
#   inflating: test/face03794.jpg
#   inflating: test/face04283.jpg
#   inflating: test/face04456.jpg
#   inflating: test/face03797.jpg
#   inflating: test/face03136.jpg
#   inflating: test/face06116.jpg
#   inflating: test/face00156.jpg
#   inflating: test/face05943.jpg
#   inflating: test/face02966.jpg
#   inflating: test/face03681.jpg
#   inflating: test/face04597.jpg
#   inflating: test/face04648.jpg
#   inflating: test/face00909.jpg
#   inflating: test/face04373.jpg
#   inflating: test/face04940.jpg
#   inflating: test/face04933.jpg
#   inflating: test/face05140.jpg
#   inflating: test/face00655.jpg
#   inflating: test/face04799.jpg
#   inflating: test/face04689.jpg
#   inflating: test/face00607.jpg
#   inflating: test/face03902.jpg
#   inflating: test/face00109.jpg
#   inflating: test/face00311.jpg
#   inflating: test/face04470.jpg
#   inflating: test/face05020.jpg
#   inflating: test/face04513.jpg
#   inflating: test/face01964.jpg
#   inflating: test/face01181.jpg
#   inflating: test/face05576.jpg
#   inflating: test/face01068.jpg
#   inflating: test/face01936.jpg
#   inflating: test/face01947.jpg
#   inflating: test/face04892.jpg
#   inflating: test/face02431.jpg
#   inflating: test/face05373.jpg
#   inflating: test/face00030.jpg
#   inflating: test/face04469.jpg
#   inflating: test/face03956.jpg
#   inflating: test/face00638.jpg
#   inflating: test/face01793.jpg
#   inflating: test/face02024.jpg
#   inflating: test/face00017.jpg
#   inflating: test/face01817.jpg
#   inflating: test/face02891.jpg
#   inflating: test/face02208.jpg
#   inflating: test/face01377.jpg
#   inflating: test/face00457.jpg
#   inflating: test/face01398.jpg
#   inflating: test/face03757.jpg
#   inflating: test/face01844.jpg
#   inflating: test/face04353.jpg
#   inflating: test/face03758.jpg
#   inflating: test/face05085.jpg
#   inflating: test/face01518.jpg
#   inflating: test/face01096.jpg
#   inflating: test/face04936.jpg
#   inflating: test/face00608.jpg
#   inflating: test/face03074.jpg
#   inflating: test/face00605.jpg
#   inflating: test/face00988.jpg
#   inflating: test/face02389.jpg
#   inflating: test/face04835.jpg
#   inflating: test/face02158.jpg
#   inflating: test/face00594.jpg
#   inflating: test/face02566.jpg
#   inflating: test/face02560.jpg
#   inflating: test/face00023.jpg
#   inflating: test/face05441.jpg
#   inflating: test/face03896.jpg
#   inflating: test/face00021.jpg
#   inflating: test/face01098.jpg
#   inflating: test/face00810.jpg
#   inflating: test/face02263.jpg
#   inflating: test/face04735.jpg
#   inflating: test/face03875.jpg
#   inflating: test/face01379.jpg
#   inflating: test/face00579.jpg
#   inflating: test/face04155.jpg
#   inflating: test/face01993.jpg
#   inflating: test/face02786.jpg
#   inflating: test/face00575.jpg
#   inflating: test/face02567.jpg
#   inflating: test/face01933.jpg
#   inflating: test/face05438.jpg
#   inflating: test/face02020.jpg
#   inflating: test/face02490.jpg
#   inflating: test/face03850.jpg
#   inflating: test/face00127.jpg
#   inflating: test/face02083.jpg
#   inflating: test/face01704.jpg
#   inflating: test/face05429.jpg
#   inflating: test/face02040.jpg
#   inflating: test/face03110.jpg
#   inflating: test/face02848.jpg
#   inflating: test/face03989.jpg
#   inflating: test/face03487.jpg
#   inflating: test/face04917.jpg
#   inflating: test/face01161.jpg
#   inflating: test/face00547.jpg
#   inflating: test/face05614.jpg
#   inflating: test/face05452.jpg
#   inflating: test/face03822.jpg
#   inflating: test/face00924.jpg
#   inflating: test/face05464.jpg
#   inflating: test/face03606.jpg
#   inflating: test/face03873.jpg
#   inflating: test/face00280.jpg
#   inflating: test/face05360.jpg
#   inflating: test/face01525.jpg
#   inflating: test/face01668.jpg
#   inflating: test/face00730.jpg
#   inflating: test/face05420.jpg
#   inflating: test/face05582.jpg
#   inflating: test/face01902.jpg
#   inflating: test/face03364.jpg
#   inflating: test/face03407.jpg
#   inflating: test/face01546.jpg
#   inflating: test/face03696.jpg
#   inflating: test/face01657.jpg
#   inflating: test/face05587.jpg
#   inflating: test/face02439.jpg
#   inflating: test/face05718.jpg
#   inflating: test/face06030.jpg
#   inflating: test/face03456.jpg
#   inflating: test/face05920.jpg
#   inflating: test/face05623.jpg
#   inflating: test/face03225.jpg
#   inflating: test/face05886.jpg
#   inflating: test/face01153.jpg
#   inflating: test/face05924.jpg
#   inflating: test/face01239.jpg
#   inflating: test/face02016.jpg
#   inflating: test/face05260.jpg
#   inflating: test/face03776.jpg
#   inflating: test/face03686.jpg
#   inflating: test/face05967.jpg
#   inflating: test/face03880.jpg
#   inflating: test/face02067.jpg
#   inflating: test/face01477.jpg
#   inflating: test/face03071.jpg
#   inflating: test/face02145.jpg
#   inflating: test/face00371.jpg
#   inflating: test/face01313.jpg
#   inflating: test/face04258.jpg
#   inflating: test/face03041.jpg
#   inflating: test/face02188.jpg
#   inflating: test/face06075.jpg
#   inflating: test/face01430.jpg
#   inflating: test/face04585.jpg
#   inflating: test/face02264.jpg
#   inflating: test/face00838.jpg
#   inflating: test/face04589.jpg
#   inflating: test/face03347.jpg
#   inflating: test/face01100.jpg
#   inflating: test/face04020.jpg
#   inflating: test/face06257.jpg
#   inflating: test/face04590.jpg
#   inflating: test/face02200.jpg
#   inflating: test/face05115.jpg
#   inflating: test/face04454.jpg
#   inflating: test/face04427.jpg
#   inflating: test/face00125.jpg
#   inflating: test/face03536.jpg
#   inflating: test/face02732.jpg
#   inflating: test/face01441.jpg
#   inflating: test/face04360.jpg
#   inflating: test/face00904.jpg
#   inflating: test/face03987.jpg
#   inflating: test/face02801.jpg
#   inflating: test/face04040.jpg
#   inflating: test/face04947.jpg
#   inflating: test/face04042.jpg
#   inflating: test/face03024.jpg
#   inflating: test/face05769.jpg
#   inflating: test/face03157.jpg
#   inflating: test/face01678.jpg
#   inflating: test/face05726.jpg
#   inflating: test/face00996.jpg
#   inflating: test/face02821.jpg
#   inflating: test/face01099.jpg
#   inflating: test/face00351.jpg
#   inflating: test/face04558.jpg
#   inflating: test/face06226.jpg
#   inflating: test/face02166.jpg
#   inflating: test/face05446.jpg
#   inflating: test/face02038.jpg
#   inflating: test/face05974.jpg
#   inflating: test/face04725.jpg
#   inflating: test/face01326.jpg
#   inflating: test/face00141.jpg
#   inflating: test/face00751.jpg
#   inflating: test/face04893.jpg
#   inflating: test/face02365.jpg
#   inflating: test/face05671.jpg
#   inflating: test/face03053.jpg
#   inflating: test/face05424.jpg
#   inflating: test/face06267.jpg
#   inflating: test/face02627.jpg
#   inflating: test/face01265.jpg
#   inflating: test/face03960.jpg
#   inflating: test/face00862.jpg
#   inflating: test/face04778.jpg
#   inflating: test/face02711.jpg
#   inflating: test/face05649.jpg
#   inflating: test/face05135.jpg
#   inflating: test/face03309.jpg
#   inflating: test/face05110.jpg
#   inflating: test/face05459.jpg
#   inflating: test/face03562.jpg
#   inflating: test/face01799.jpg
#   inflating: test/face03357.jpg
#   inflating: test/face03147.jpg
#   inflating: test/face04841.jpg
#   inflating: test/face00469.jpg
#   inflating: test/face04290.jpg
#   inflating: test/face01014.jpg
#   inflating: test/face03020.jpg
#   inflating: test/face00179.jpg
#   inflating: test/face01020.jpg
#   inflating: test/face03410.jpg
#   inflating: test/face02546.jpg
#   inflating: test/face03327.jpg
#   inflating: test/face01420.jpg
#   inflating: test/face05097.jpg
#   inflating: test/face05604.jpg
#   inflating: test/face00558.jpg
#   inflating: test/face03437.jpg
#   inflating: test/face00887.jpg
#   inflating: test/face02866.jpg
#   inflating: test/face02518.jpg
#   inflating: test/face00214.jpg
#   inflating: test/face00770.jpg
#   inflating: test/face01297.jpg
#   inflating: test/face03899.jpg
#   inflating: test/face06140.jpg
#   inflating: test/face06250.jpg
#   inflating: test/face05673.jpg
#   inflating: test/face00235.jpg
#   inflating: test/face05344.jpg
#   inflating: test/face03719.jpg
#   inflating: test/face03142.jpg
#   inflating: test/face02432.jpg
#   inflating: test/face02035.jpg
#   inflating: test/face02008.jpg
#   inflating: test/face01552.jpg
#   inflating: test/face01418.jpg
#   inflating: test/face00382.jpg
#   inflating: test/face04089.jpg
#   inflating: test/face04169.jpg
#   inflating: test/face03025.jpg
#   inflating: test/face01512.jpg
#   inflating: test/face05565.jpg
#   inflating: test/face00908.jpg
#   inflating: test/face01976.jpg
#   inflating: test/face05199.jpg
#   inflating: test/face04195.jpg
#   inflating: test/face05652.jpg
#   inflating: test/face05507.jpg
#   inflating: test/face00502.jpg
#   inflating: test/face04945.jpg
#   inflating: test/face00817.jpg
#   inflating: test/face01928.jpg
#   inflating: test/face05264.jpg
#   inflating: test/face02931.jpg
#   inflating: test/face05985.jpg
#   inflating: test/face05715.jpg
#   inflating: test/face05563.jpg
#   inflating: test/face03359.jpg
#   inflating: test/face05492.jpg
#   inflating: test/face02565.jpg
#   inflating: test/face05824.jpg
#   inflating: test/face01396.jpg
#   inflating: test/face05977.jpg
#   inflating: test/face05486.jpg
#   inflating: test/face02714.jpg
#   inflating: test/face04005.jpg
#   inflating: test/face05751.jpg
#   inflating: test/face03017.jpg
#   inflating: test/face02506.jpg
#   inflating: test/face05018.jpg
#   inflating: test/face00343.jpg
#   inflating: test/face04888.jpg
#   inflating: test/face02326.jpg
#   inflating: test/face05067.jpg
#   inflating: test/face06146.jpg
#   inflating: test/face03532.jpg
#   inflating: test/face05205.jpg
#   inflating: test/face04584.jpg
#   inflating: test/face00531.jpg
#   inflating: test/face00234.jpg
#   inflating: test/face02859.jpg
#   inflating: test/face04961.jpg
#   inflating: test/face05764.jpg
#   inflating: test/face03127.jpg
#   inflating: test/face05338.jpg
#   inflating: test/face02775.jpg
#   inflating: test/face00316.jpg
#   inflating: test/face05765.jpg
#   inflating: test/face01388.jpg
#   inflating: test/face01854.jpg
#   inflating: test/face00438.jpg
#   inflating: test/face04826.jpg
#   inflating: test/face04600.jpg
#   inflating: test/face04591.jpg
#   inflating: test/face04320.jpg
#   inflating: test/face04931.jpg
#   inflating: test/face01979.jpg
#   inflating: test/face01665.jpg
#   inflating: test/face03491.jpg
#   inflating: test/face03302.jpg
#   inflating: test/face00847.jpg
#   inflating: test/face04651.jpg
#   inflating: test/face01582.jpg
#   inflating: test/face02752.jpg
#   inflating: test/face05451.jpg
#   inflating: test/face05787.jpg
#   inflating: test/face06176.jpg
#   inflating: test/face01417.jpg
#   inflating: test/face04259.jpg
#   inflating: test/face00220.jpg
#   inflating: test/face00960.jpg
#   inflating: test/face05906.jpg
#   inflating: test/face00545.jpg
#   inflating: test/face05930.jpg
#   inflating: test/face06085.jpg
#   inflating: test/face04861.jpg
#   inflating: test/face02201.jpg
#   inflating: test/face00312.jpg
#   inflating: test/face04525.jpg
#   inflating: test/face03462.jpg
#   inflating: test/face05512.jpg
#   inflating: test/face00930.jpg
#   inflating: test/face05425.jpg
#   inflating: test/face04761.jpg
#   inflating: test/face00275.jpg
#   inflating: test/face01965.jpg
#   inflating: test/face00589.jpg
#   inflating: test/face01780.jpg
#   inflating: test/face00925.jpg
#   inflating: test/face05112.jpg
#   inflating: test/face05656.jpg
#   inflating: test/face03512.jpg
#   inflating: test/face03695.jpg
#   inflating: test/face01019.jpg
#   inflating: test/face04032.jpg
#   inflating: test/face02562.jpg
#   inflating: test/face06237.jpg
#   inflating: test/face00362.jpg
#   inflating: test/face04726.jpg
#   inflating: test/face03320.jpg
#   inflating: test/face02757.jpg
#   inflating: test/face05279.jpg
#   inflating: test/face04292.jpg
#   inflating: test/face02341.jpg
#   inflating: test/face01783.jpg
#   inflating: test/face04211.jpg
#   inflating: test/face01347.jpg
#   inflating: test/face04615.jpg
#   inflating: test/face04438.jpg
#   inflating: test/face05074.jpg
#   inflating: test/face04286.jpg
#   inflating: test/face02574.jpg
#   inflating: test/face04033.jpg
#   inflating: test/face02588.jpg
#   inflating: test/face05816.jpg
#   inflating: test/face05371.jpg
#   inflating: test/face03848.jpg
#   inflating: test/face01255.jpg
#   inflating: test/face00452.jpg
#   inflating: test/face01350.jpg
#   inflating: test/face01104.jpg
#   inflating: test/face01874.jpg
#   inflating: test/face04238.jpg
#   inflating: test/face02637.jpg
#   inflating: test/face02194.jpg
#   inflating: test/face00359.jpg
#   inflating: test/face00136.jpg
#   inflating: test/face01303.jpg
#   inflating: test/face00508.jpg
#   inflating: test/face01037.jpg
#   inflating: test/face05432.jpg
#   inflating: test/face01319.jpg
#   inflating: test/face03239.jpg
#   inflating: test/face01004.jpg
#   inflating: test/face05369.jpg
#   inflating: test/face01148.jpg
#   inflating: test/face00534.jpg
#   inflating: test/face03528.jpg
#   inflating: test/face01280.jpg
#   inflating: test/face00047.jpg
#   inflating: test/face03109.jpg
#   inflating: test/face05704.jpg
#   inflating: test/face01654.jpg
#   inflating: test/face05192.jpg
#   inflating: test/face01227.jpg
#   inflating: test/face04897.jpg
#   inflating: test/face00191.jpg
#   inflating: test/face05350.jpg
#   inflating: test/face02470.jpg
#   inflating: test/face01932.jpg
#   inflating: test/face05297.jpg
#   inflating: test/face00348.jpg
#   inflating: test/face02792.jpg
#   inflating: test/face03675.jpg
#   inflating: test/face05583.jpg
#   inflating: test/face02311.jpg
#   inflating: test/face00724.jpg
#   inflating: test/face03971.jpg
#   inflating: test/face00083.jpg
#   inflating: test/face03761.jpg
#   inflating: test/face04131.jpg
#   inflating: test/face06127.jpg
#   inflating: test/face01528.jpg
#   inflating: test/face02983.jpg
#   inflating: test/face01994.jpg
#   inflating: test/face04055.jpg
#   inflating: test/face00878.jpg
#   inflating: test/face00476.jpg
#   inflating: test/face01448.jpg
#   inflating: test/face02889.jpg
#   inflating: test/face06106.jpg
#   inflating: test/face03344.jpg
#   inflating: test/face00027.jpg
#   inflating: test/face02607.jpg
#   inflating: test/face00962.jpg
#   inflating: test/face04183.jpg
#   inflating: test/face00374.jpg
#   inflating: test/face02368.jpg
#   inflating: test/face00538.jpg
#   inflating: test/face00646.jpg
#   inflating: test/face01752.jpg
#   inflating: test/face00010.jpg
#   inflating: test/face00354.jpg
#   inflating: test/face00402.jpg
#   inflating: test/face05543.jpg
#   inflating: test/face04601.jpg
#   inflating: test/face03576.jpg
#   inflating: test/face00828.jpg
#   inflating: test/face05616.jpg
#   inflating: test/face01183.jpg
#   inflating: test/face01822.jpg
#   inflating: test/face00781.jpg
#   inflating: test/face02164.jpg
#   inflating: test/face01860.jpg
#   inflating: test/face01046.jpg
#   inflating: test/face03951.jpg
#   inflating: test/face04270.jpg
#   inflating: test/face04552.jpg
#   inflating: test/face00436.jpg
#   inflating: test/face02679.jpg
#   inflating: test/face03788.jpg
#   inflating: test/face04556.jpg
#   inflating: test/face00979.jpg
#   inflating: test/face04989.jpg
#   inflating: test/face02445.jpg
#   inflating: test/face00976.jpg
#   inflating: test/face04426.jpg
#   inflating: test/face04894.jpg
#   inflating: test/face05433.jpg
#   inflating: test/face03178.jpg
#   inflating: test/face01564.jpg
#   inflating: test/face01527.jpg
#   inflating: test/face06161.jpg
#   inflating: test/face04101.jpg
#   inflating: test/face00042.jpg
#   inflating: test/face04711.jpg
#   inflating: test/face02985.jpg
#   inflating: test/face01906.jpg
#   inflating: test/face01352.jpg
#   inflating: test/face06243.jpg
#   inflating: test/face02375.jpg
#   inflating: test/face03988.jpg
#   inflating: test/face03201.jpg
#   inflating: test/face01011.jpg
#   inflating: test/face03438.jpg
#   inflating: test/face06003.jpg
#   inflating: test/face03099.jpg
#   inflating: test/face05041.jpg
#   inflating: test/face01361.jpg
#   inflating: test/face04177.jpg
#   inflating: test/face02825.jpg
#   inflating: test/face02665.jpg
#   inflating: test/face01970.jpg
#   inflating: test/face05969.jpg
#   inflating: test/face02762.jpg
#   inflating: test/face01806.jpg
#   inflating: test/face01886.jpg
#   inflating: test/face01501.jpg
#   inflating: test/face05308.jpg
#   inflating: test/face06097.jpg
#   inflating: test/face00701.jpg
#   inflating: test/face01908.jpg
#   inflating: test/face03508.jpg
#   inflating: test/face01213.jpg
#   inflating: test/face04614.jpg
#   inflating: test/face05664.jpg
#   inflating: test/face01101.jpg
#   inflating: test/face02006.jpg
#   inflating: test/face02563.jpg
#   inflating: test/face03237.jpg
#   inflating: test/face00315.jpg
#   inflating: test/face04624.jpg
#   inflating: test/face03586.jpg
#   inflating: test/face03397.jpg
#   inflating: test/face00615.jpg
#   inflating: test/face01287.jpg
#   inflating: test/face01324.jpg
#   inflating: test/face04026.jpg
#   inflating: test/face03418.jpg
#   inflating: test/face03581.jpg
#   inflating: test/face05785.jpg
#   inflating: test/face04409.jpg
#   inflating: test/face01078.jpg
#   inflating: test/face01191.jpg
#   inflating: test/face05274.jpg
#   inflating: test/face00807.jpg
#   inflating: test/face05894.jpg
#   inflating: test/face03801.jpg
#   inflating: test/face01052.jpg
#   inflating: test/face01625.jpg
#   inflating: test/face05255.jpg
#   inflating: test/face00609.jpg
#   inflating: test/face05439.jpg
#   inflating: test/face02744.jpg
#   inflating: test/face04772.jpg
#   inflating: test/face04729.jpg
#   inflating: test/face05453.jpg
#   inflating: test/face05508.jpg
#   inflating: test/face05519.jpg
#   inflating: test/face00824.jpg
#   inflating: test/face03812.jpg
#   inflating: test/face05381.jpg
#   inflating: test/face05372.jpg
#   inflating: test/face05558.jpg
#   inflating: test/face00944.jpg
#   inflating: test/face02473.jpg
#   inflating: test/face02031.jpg
#   inflating: test/face04309.jpg
#   inflating: test/face05030.jpg
#   inflating: test/face06137.jpg
#   inflating: test/face00077.jpg
#   inflating: test/face03975.jpg
#   inflating: test/face05752.jpg
#   inflating: test/face00038.jpg
#   inflating: test/face00305.jpg
#   inflating: test/face00580.jpg
#   inflating: test/face00725.jpg
#   inflating: test/face01782.jpg
#   inflating: test/face03978.jpg
#   inflating: test/face00363.jpg
#   inflating: test/face04820.jpg
#   inflating: test/face00641.jpg
#   inflating: test/face01187.jpg
#   inflating: test/face04252.jpg
#   inflating: test/face02944.jpg
#   inflating: test/face03068.jpg
#   inflating: test/face02151.jpg
#   inflating: test/face02418.jpg
#   inflating: test/face06148.jpg
#   inflating: test/face01842.jpg
#   inflating: test/face03887.jpg
#   inflating: test/face04012.jpg
#   inflating: test/face03289.jpg
#   inflating: test/face05198.jpg
#   inflating: test/face02551.jpg
#   inflating: test/face05647.jpg
#   inflating: test/face02102.jpg
#   inflating: test/face05547.jpg
#   inflating: test/face02629.jpg
#   inflating: test/face05040.jpg
#   inflating: test/face99997.jpg
#   inflating: test/face05180.jpg
#   inflating: test/face02796.jpg
#   inflating: test/face00932.jpg
# ...
#   inflating: test/face05241.jpg
#   inflating: test/face04706.jpg
#   inflating: test/face03331.jpg
#   inflating: test/face03262.jpg
#   inflating: test/face01966.jpg
#   inflating: test/face00626.jpg
#   inflating: test/face02307.jpg
#   inflating: test/face00219.jpg
#   inflating: test/face03120.jpg
#   inflating: test/face03457.jpg
#   inflating: test/face02703.jpg
#   inflating: test/face03374.jpg
#   inflating: test/face02716.jpg
#   inflating: test/face01630.jpg
#   inflating: test/face04990.jpg
#   inflating: test/face04572.jpg
#   inflating: test/face03967.jpg
#   inflating: test/face01505.jpg
#   inflating: test/face05725.jpg
#   inflating: test/face02426.jpg
#   inflating: test/face03444.jpg
#   inflating: test/face05484.jpg
#   inflating: test/face00390.jpg
#   inflating: test/face00171.jpg
#   inflating: test/face04117.jpg
#   inflating: test/face03034.jpg
#   inflating: test/face01122.jpg
#   inflating: test/face01598.jpg
#   inflating: test/face06230.jpg
#   inflating: test/face04801.jpg
#   inflating: test/face04998.jpg
#   inflating: test/face05665.jpg
#   inflating: test/face05066.jpg
#   inflating: test/face03322.jpg
#   inflating: test/face03725.jpg
#   inflating: test/face04867.jpg
#   inflating: test/face03406.jpg
#   inflating: test/face05914.jpg
#   inflating: test/face01132.jpg
#   inflating: test/face04954.jpg
#   inflating: test/face02925.jpg
#   inflating: test/face01871.jpg
#   inflating: test/face03213.jpg
#   inflating: test/face04265.jpg
#   inflating: test/face03870.jpg
#   inflating: test/face04718.jpg
#   inflating: test/face01212.jpg
#   inflating: test/face02618.jpg
#   inflating: test/face05556.jpg
#   inflating: test/face04022.jpg
#   inflating: test/face01773.jpg
#   inflating: test/face00573.jpg
#   inflating: test/face02324.jpg
#   inflating: test/face04061.jpg
#   inflating: test/face03882.jpg
#   inflating: test/face05630.jpg
#   inflating: test/face04920.jpg
#   inflating: test/face05343.jpg
#   inflating: test/face05354.jpg
#   inflating: test/face02153.jpg
#   inflating: test/face02603.jpg
#   inflating: test/face00154.jpg
#   inflating: test/face04274.jpg
#   inflating: test/face04568.jpg
#   inflating: test/face05497.jpg
#   inflating: test/face05323.jpg
#   inflating: test/face01974.jpg
#   inflating: test/face02862.jpg
#   inflating: test/face02822.jpg
#   inflating: test/face05503.jpg
#   inflating: test/face02516.jpg
#   inflating: test/face05904.jpg
#   inflating: test/face03783.jpg
#   inflating: test/face05134.jpg
#   inflating: test/face03643.jpg
#   inflating: test/face01648.jpg
#   inflating: test/face02366.jpg
#   inflating: test/face01502.jpg
#   inflating: test/face04955.jpg
#   inflating: test/face02846.jpg
#   inflating: test/face01588.jpg
#   inflating: test/face02876.jpg
#   inflating: test/face06055.jpg
#   inflating: test/face03415.jpg
#   inflating: test/face00537.jpg
#   inflating: test/face01433.jpg
#   inflating: test/face05019.jpg
#   inflating: test/face03759.jpg
#   inflating: test/face01422.jpg
#   inflating: test/face04239.jpg
#   inflating: test/face00159.jpg
#   inflating: test/face01644.jpg
#   inflating: test/face00439.jpg
#   inflating: test/face00808.jpg
#   inflating: test/face05849.jpg
#   inflating: test/face03356.jpg
#   inflating: test/face00259.jpg
#   inflating: test/face00636.jpg
#   inflating: test/face02979.jpg
#   inflating: test/face00244.jpg
#   inflating: test/face00767.jpg
#   inflating: test/face01152.jpg
#   inflating: test/face01306.jpg
#   inflating: test/face01863.jpg
#   inflating: test/face00347.jpg
#   inflating: test/face05387.jpg
#   inflating: test/face00061.jpg
#   inflating: test/face05549.jpg
#   inflating: test/face05409.jpg
#   inflating: test/face02308.jpg
#   inflating: test/face01137.jpg
#   inflating: test/face05633.jpg
#   inflating: test/face02558.jpg
#   inflating: test/face00100.jpg
#   inflating: test/face00912.jpg
#   inflating: test/face03900.jpg
#   inflating: test/face05645.jpg
#   inflating: test/face00635.jpg
#   inflating: test/face02420.jpg
#   inflating: test/face05670.jpg
#   inflating: test/face03497.jpg
#   inflating: test/face05143.jpg
#   inflating: test/face00440.jpg
#   inflating: test/face05391.jpg
#   inflating: test/face01751.jpg
#   inflating: test/face02216.jpg
#   inflating: test/face01542.jpg
#   inflating: test/face04205.jpg
#   inflating: test/face00954.jpg
#   inflating: test/face02761.jpg
#   inflating: test/face02681.jpg
#   inflating: test/face00122.jpg
#   inflating: test/face03211.jpg
#   inflating: test/face04557.jpg
#   inflating: test/face03042.jpg
#   inflating: test/face02234.jpg
#   inflating: test/face06088.jpg
#   inflating: test/face06069.jpg
#   inflating: test/face00800.jpg
#   inflating: test/face00903.jpg
#   inflating: test/face06020.jpg
#   inflating: test/face06104.jpg
#   inflating: test/face02745.jpg
#   inflating: test/face04052.jpg
#   inflating: test/face02427.jpg
#   inflating: test/face05366.jpg
#   inflating: test/face00139.jpg
#   inflating: test/face01745.jpg
#   inflating: test/face05185.jpg
#   inflating: test/face05075.jpg
#   inflating: test/face03856.jpg
#   inflating: test/face03060.jpg
#   inflating: test/face05400.jpg
#   inflating: test/face02400.jpg
#   inflating: test/face01414.jpg
#   inflating: test/face01977.jpg
#   inflating: test/face01207.jpg
#   inflating: test/face03933.jpg
#   inflating: test/face01446.jpg
#   inflating: test/face02616.jpg
#   inflating: test/face01510.jpg
#   inflating: test/face02157.jpg
#   inflating: test/face01018.jpg
#   inflating: test/face04194.jpg
#   inflating: test/face02080.jpg
#   inflating: test/face01080.jpg
#   inflating: test/face00401.jpg
#   inflating: test/face04924.jpg
#   inflating: test/face01492.jpg
#   inflating: test/face00320.jpg
#   inflating: test/face01621.jpg
#   inflating: test/face06105.jpg
#   inflating: test/face03672.jpg
#   inflating: test/face00763.jpg
#   inflating: test/face00792.jpg
#   inflating: test/face01321.jpg
#   inflating: test/face06213.jpg
#   inflating: test/face01208.jpg
#   inflating: test/face01027.jpg
#   inflating: test/face02458.jpg
#   inflating: test/face05505.jpg
#   inflating: test/face02760.jpg
#   inflating: test/face06123.jpg
#   inflating: test/face04682.jpg
#   inflating: test/face04520.jpg
#   inflating: test/face00959.jpg
#   inflating: test/face05557.jpg
#   inflating: test/face05392.jpg
#   inflating: test/face05833.jpg
#   inflating: test/face03185.jpg
#   inflating: test/face06014.jpg
#   inflating: test/face04795.jpg
#   inflating: test/face03104.jpg
#   inflating: test/face05228.jpg
#   inflating: test/face04635.jpg
#   inflating: test/face01493.jpg
#   inflating: test/face00849.jpg
#   inflating: test/face00182.jpg
#   inflating: test/face01087.jpg
#   inflating: test/face04468.jpg
#   inflating: test/face05498.jpg
#   inflating: test/face03064.jpg
#   inflating: test/face02156.jpg
#   inflating: test/face00498.jpg
#   inflating: test/face01064.jpg
#   inflating: test/face02748.jpg
#   inflating: test/face02646.jpg
#   inflating: test/face01177.jpg
#   inflating: test/face00026.jpg
#   inflating: test/face02481.jpg
#   inflating: test/face02836.jpg
#   inflating: test/face00014.jpg
#   inflating: test/face03063.jpg
#   inflating: test/face00634.jpg
#   inflating: test/face02779.jpg
#   inflating: test/face00777.jpg
#   inflating: test/face00784.jpg
#   inflating: test/face03383.jpg
#   inflating: test/face02954.jpg
#   inflating: test/face03304.jpg
#   inflating: test/face04048.jpg
#   inflating: test/face00958.jpg
#   inflating: test/face00961.jpg
#   inflating: test/face01760.jpg
#   inflating: test/face03084.jpg
#   inflating: test/face05238.jpg
#   inflating: test/face00177.jpg
#   inflating: test/face05973.jpg
#   inflating: test/face04808.jpg
#   inflating: test/face04963.jpg
#   inflating: test/face01449.jpg
#   inflating: test/face05524.jpg
#   inflating: test/face01443.jpg
#   inflating: test/face03458.jpg
#   inflating: test/face03821.jpg
#   inflating: test/face03339.jpg
#   inflating: test/face05791.jpg
#   inflating: test/face04349.jpg
#   inflating: test/face04609.jpg
#   inflating: test/face00108.jpg
#   inflating: test/face06093.jpg
#   inflating: test/face04921.jpg
#   inflating: test/face04864.jpg
#   inflating: test/face03122.jpg
#   inflating: test/face05273.jpg
#   inflating: test/face03100.jpg
#   inflating: test/face03232.jpg
#   inflating: test/face04431.jpg
#   inflating: test/face02257.jpg
#   inflating: test/face04901.jpg
#   inflating: test/face02255.jpg
#   inflating: test/face02613.jpg
#   inflating: test/face05472.jpg
#   inflating: test/face04972.jpg
#   inflating: test/face00914.jpg
#   inflating: test/face02054.jpg
#   inflating: test/face05170.jpg
#   inflating: test/face04329.jpg
#   inflating: test/face03712.jpg
#   inflating: test/face01089.jpg
#   inflating: test/face01563.jpg
#   inflating: test/face05975.jpg
#   inflating: test/face02161.jpg
#   inflating: test/face03862.jpg
#   inflating: test/face04953.jpg
#   inflating: test/face00926.jpg
#   inflating: test/face00466.jpg
#   inflating: test/face04065.jpg
#   inflating: test/face01676.jpg
#   inflating: test/face02497.jpg
#   inflating: test/face02729.jpg
#   inflating: test/face03210.jpg
#   inflating: test/face04817.jpg
#   inflating: test/face05794.jpg
#   inflating: test/face03000.jpg
#   inflating: test/face01680.jpg
#   inflating: test/face02440.jpg
#   inflating: test/face01228.jpg
#   inflating: test/face03417.jpg
#   inflating: test/face05848.jpg
#   inflating: test/face00574.jpg
#   inflating: test/face00297.jpg
#   inflating: test/face01327.jpg
#   inflating: test/face01649.jpg
#   inflating: test/face03350.jpg
#   inflating: test/face03430.jpg
#   inflating: test/face06177.jpg
#   inflating: test/face01996.jpg
#   inflating: test/face01051.jpg
#   inflating: test/face04807.jpg
#   inflating: test/face01798.jpg
#   inflating: test/face02241.jpg
#   inflating: test/face05644.jpg
#   inflating: test/face05972.jpg
#   inflating: test/face06202.jpg
#   inflating: test/face01222.jpg
#   inflating: test/face01731.jpg
#   inflating: test/face06122.jpg
#   inflating: test/face03414.jpg
#   inflating: test/face05826.jpg
#   inflating: test/face01236.jpg
#   inflating: test/face01385.jpg
#   inflating: test/face04695.jpg
#   inflating: test/face02112.jpg
#   inflating: test/face01639.jpg
#   inflating: test/face00535.jpg
#   inflating: test/face05419.jpg
#   inflating: test/face02611.jpg
#   inflating: test/face03134.jpg
#   inflating: test/face01496.jpg
#   inflating: test/face02220.jpg
#   inflating: test/face01755.jpg
#   inflating: test/face02285.jpg
#   inflating: test/face00880.jpg
#   inflating: test/face02692.jpg
#   inflating: test/face00972.jpg
#   inflating: test/face04781.jpg
#   inflating: test/face02377.jpg
#   inflating: test/face03219.jpg
#   inflating: test/face00185.jpg
#   inflating: test/face01777.jpg
#   inflating: test/face02968.jpg
#   inflating: test/face00881.jpg
#   inflating: test/face00679.jpg
#   inflating: test/face01503.jpg
#   inflating: test/face00974.jpg
#   inflating: test/face03016.jpg
#   inflating: test/face04821.jpg
#   inflating: test/face03114.jpg
#   inflating: test/face01789.jpg
#   inflating: test/face02661.jpg
#   inflating: test/face00993.jpg
#   inflating: test/face02391.jpg
#   inflating: test/face05573.jpg
#   inflating: test/face03244.jpg
#   inflating: test/face00481.jpg
#   inflating: test/face05888.jpg
#   inflating: test/face04800.jpg
#   inflating: test/face02591.jpg
#   inflating: test/face00576.jpg
#   inflating: test/face02911.jpg
#   inflating: test/face02870.jpg
#   inflating: test/face05594.jpg
#   inflating: test/face01314.jpg
#   inflating: test/face04812.jpg
#   inflating: test/face01474.jpg
#   inflating: test/face02647.jpg
#   inflating: test/face01949.jpg
#   inflating: test/face05147.jpg
#   inflating: test/face01056.jpg
#   inflating: test/face03661.jpg
#   inflating: test/face00250.jpg
#   inflating: test/face01426.jpg
#   inflating: test/face03706.jpg
#   inflating: test/face01547.jpg
#   inflating: test/face05166.jpg
#   inflating: test/face01482.jpg
#   inflating: test/face02265.jpg
#   inflating: test/face05407.jpg
#   inflating: test/face04041.jpg
#   inflating: test/face03274.jpg
#   inflating: test/face04899.jpg
#   inflating: test/face01339.jpg
#   inflating: test/face04063.jpg
#   inflating: test/face05317.jpg
#   inflating: test/face00771.jpg
#   inflating: test/face01423.jpg
#   inflating: test/face04289.jpg
#   inflating: test/face06174.jpg
#   inflating: test/face01480.jpg
#   inflating: test/face05981.jpg
#   inflating: test/face00036.jpg
#   inflating: test/face05141.jpg
#   inflating: test/face01215.jpg
#   inflating: test/face01487.jpg
#   inflating: test/face01744.jpg
#   inflating: test/face01728.jpg
#   inflating: test/face01175.jpg
#   inflating: test/face01363.jpg
#   inflating: test/face00603.jpg
#   inflating: test/face02500.jpg
#   inflating: test/face04352.jpg
#   inflating: test/face01737.jpg
#   inflating: test/face02106.jpg
#   inflating: test/face00765.jpg
#   inflating: test/face05853.jpg
#   inflating: test/face04612.jpg
#   inflating: test/face01533.jpg
#   inflating: test/face06037.jpg
#   inflating: test/face03552.jpg
#   inflating: test/face02845.jpg
#   inflating: test/face03583.jpg
#   inflating: test/face00995.jpg
#   inflating: test/face00809.jpg
#   inflating: test/face01926.jpg
#   inflating: test/face02987.jpg
#   inflating: test/face00056.jpg
#   inflating: test/face06198.jpg
#   inflating: test/face02767.jpg
#   inflating: test/face01999.jpg
#   inflating: test/face03886.jpg
#   inflating: test/face02152.jpg
#   inflating: test/face05415.jpg
#   inflating: test/face04860.jpg
#   inflating: test/face06130.jpg
#   inflating: test/face02373.jpg
#   inflating: test/face03894.jpg
#   inflating: test/face05515.jpg
#   inflating: test/face05734.jpg
#   inflating: test/face01170.jpg
#   inflating: test/face03367.jpg
#   inflating: test/face00462.jpg
#   inflating: test/face05736.jpg
#   inflating: test/face00560.jpg
#   inflating: test/face00447.jpg
#   inflating: test/face03728.jpg
#   inflating: test/face01453.jpg
#   inflating: test/face03720.jpg
#   inflating: test/face00218.jpg
#   inflating: test/face00011.jpg
#   inflating: test/face02296.jpg

# %% [markdown]
# ## Obtain the testing set
# Differently from the creation of the training set (where we chose randomicaly from positive or negative samples), here we have to create the tesing-set based on the "sample_submission.csv" files (which contain the testing pairs).
#
# So what we have to do is:
# 1. Open the *sample_submission.csv* file (that has tuple in the face05508.jpg-face01210.jpg format, the faces.jpg images are on the "test" folder)
# 2. Get the path of the 2 images
# 3. Open the image (the path refers to the images in the "test" folder)
# 4. Apply the transformation

# %%
class testDataset(Dataset): #different from train dataset, because the data organized in submission.csv is different from train.csv
    
    def __init__(self,transform=None):
        self.test_df = pd.read_csv('/content/drive/MyDrive/ComputerVisionProject/kinship-dataset/sample_submission.csv')#pandas用来读取csv文件
        self.transform = transform
        
    def __getitem__(self,index):
        #data in submission.csv:
        #       img_pair               is_related
        #face05508.jpg-face01210.jpg       0
        #face05820.jpg-face03938.jpg       0
        
        img0_path = self.test_df.iloc[index].img_pair.split("-")[0]
        img1_path = self.test_df.iloc[index].img_pair.split("-")[1]
        
        img0 = Image.open('test/'+img0_path)
        img1 = Image.open('test/'+img1_path)

        if self.transform is not None:
            img0 = self.transform(img0)
            img1 = self.transform(img1)
        
        return img0, img1
    
    def __len__(self):
        return len(self.test_df)

# %%
testset = testDataset(transform=transforms.Compose([transforms.Resize((IMG_SIZE,IMG_SIZE)),
                                                                      transforms.ToTensor()
                                                                      ]))
testloader = DataLoader(testset,
                        shuffle=False,
                        num_workers=0,
                        batch_size=1)#Both extra workers and batch size lead to data out of order, the submission.csv will be out of order

# %% [markdown]
# # Prediction on the test set
# The output of the network is a tensor with two values (es tensor([[ 0.5750, -0.4568]])). The first value corresponds to NO, the second corresponds to YES. Thus, taking the index of the greatest value gives the prediction.
#
# Es: tensor([[ 0.5750, -0.4568]]). The greatest value is 0.5750, the index of the value is 0, so the output is 0 (NO KINSHIP)

# %%
#Testing impiega circa 1 minuto (per Naive) e circa 5 minuti (per reti preaddestrate)
test_df = pd.read_csv('/content/drive/MyDrive/ComputerVisionProject/kinship-dataset/sample_submission.csv')
predictions=[]
with torch.no_grad():
    for data in testloader:
        img0, img1 = data
        img0, img1 = img0.cuda(), img1.cuda()
        outputs = net(img0,img1)
        _, predicted = torch.max(outputs, 1)
        predictions = np.concatenate((predictions,predicted.cpu().numpy()),0)
        
test_df['is_related'] = predictions
test_df.to_csv("/content/drive/MyDrive/ComputerVisionProject/kinship-dataset/submission_ResNet.csv", index=False) #submission.csv should be placed directly in current fold.
test_df.head(50)#show the result to be committed
# Out:
#                        img_pair  is_related
# 0   face05508.jpg-face01210.jpg         0.0
# 1   face05750.jpg-face00898.jpg         1.0
# 2   face05820.jpg-face03938.jpg         1.0
# 3   face02104.jpg-face01172.jpg         0.0
# 4   face02428.jpg-face05611.jpg         0.0
# 5   face01219.jpg-face00274.jpg         0.0
# 6   face04262.jpg-face00555.jpg         1.0
# 7   face03697.jpg-face01892.jpg         1.0
# 8   face03524.jpg-face00319.jpg         1.0
# 9   face03410.jpg-face05368.jpg         0.0
# 10  face00292.jpg-face06004.jpg         0.0
# 11  face00353.jpg-face01203.jpg         1.0
# 12  face03140.jpg-face05223.jpg         0.0
# 13  face02915.jpg-face03312.jpg         1.0
# 14  face03012.jpg-face04103.jpg         0.0
# 15  face02240.jpg-face02336.jpg         1.0
# 16  face02131.jpg-face05209.jpg         1.0
# 17  face04105.jpg-face01209.jpg         0.0
# 18  face03565.jpg-face02509.jpg         1.0
# 19  face02836.jpg-face01540.jpg         0.0
# 20  face02832.jpg-face05386.jpg         1.0
# 21  face02596.jpg-face02913.jpg         0.0
# 22  face02231.jpg-face05835.jpg         1.0
# 23  face00451.jpg-face03664.jpg         0.0
# 24  face01644.jpg-face01682.jpg         0.0
# 25  face03988.jpg-face03379.jpg         1.0
# 26  face00908.jpg-face05944.jpg         0.0
# 27  face05117.jpg-face03498.jpg         1.0
# 28  face05466.jpg-face02942.jpg         0.0
# 29  face01537.jpg-face00187.jpg         0.0
# 30  face03609.jpg-face05219.jpg         0.0
# 31  face04820.jpg-face04526.jpg         0.0
# 32  face05963.jpg-face00176.jpg         1.0
# 33  face04372.jpg-face03101.jpg         1.0
# 34  face01496.jpg-face04980.jpg         1.0
# 35  face04215.jpg-face01123.jpg         0.0
# 36  face02624.jpg-face05000.jpg         0.0
# 37  face04434.jpg-face03376.jpg         1.0
# 38  face03417.jpg-face03461.jpg         0.0
# 39  face03142.jpg-face00593.jpg         1.0
# 40  face00094.jpg-face04094.jpg         1.0
# 41  face05700.jpg-face03910.jpg         0.0
# 42  face03620.jpg-face03203.jpg         0.0
# 43  face05074.jpg-face03806.jpg         0.0
# 44  face03836.jpg-face05917.jpg         1.0
# 45  face04495.jpg-face02846.jpg         0.0
# 46  face01690.jpg-face01033.jpg         0.0
# 47  face01766.jpg-face06057.jpg         1.0
# 48  face04896.jpg-face01845.jpg         1.0
# 49  face05468.jpg-face04688.jpg         0.0

# %%
# Salvataggio modello
saved_path = "/content/drive/MyDrive/ComputerVisionProject/pretrained_model/ResNet.pth"
torch.save(net, saved_path)
